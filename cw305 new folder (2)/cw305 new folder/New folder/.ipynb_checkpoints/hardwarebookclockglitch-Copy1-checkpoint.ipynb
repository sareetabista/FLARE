# %%
import chipwhisperer as cw
import time

# Connection
scope = cw.scope()


# Bitstream Path
# Note: Using 'r' before the string to handle backslashes correctly
bitstream = r'C:\Users\sbista\ChipWhisperer\chipwhisperer\firmware\fpgas\aes\vivado\cw305_aes.runs\impl_100t\cw305_top.bit'

# Program FPGA
target = cw.target(scope, cw.targets.CW305, bsfile=bitstream, force=True)

# Set some default CW305 settings
target.vccint_set(1.0)
#target.pll.set_cw305_vccint_settings(1.0)
print("FPGA Programmed Successfully")
# Out:
# (ChipWhisperer Target WARNING|File CW305.py:591) Using default Verilog defines (C:\Users\sbista\ChipWhisperer\chipwhisperer\software\chipwhisperer/hardware/firmware/cw305/cw305_aes_defines.v); if this is not what you want, provide them via the defines_files argument
# FPGA Programmed Successfully

# %%
# Scope Setup
scope.gain.gain = 40
scope.gain.mode = "high"
scope.adc.samples = 350
scope.adc.offset = 0
scope.adc.basic_mode = "rising_edge"
scope.trigger.triggers = "tio4"

# Clock Settings
scope.clock.extclk_freq = 10000000
scope.clock.clkgen_mul = 5
scope.clock.clkgen_div = 48
scope.clock.clkgen_freq = 10000000
scope.clock.adc_src = "clkgen_x4"
scope.clock.freq_ctr_src = "clkgen"
scope.clock.adc_phase = 175

# Glitch Setup
#scope.io.hs2 = "glitch"
scope.glitch.clk_src = 'clkgen'
scope.glitch.output = "clock_xor"
#scope.glitch.trigger_src = "ext_single" # For precise glitching per-trace
scope.glitch.trigger_src = "continuous"

# Turn on Glitch Transistors
scope.io.glitch_hp = True
scope.io.glitch_lp = True

print("Hardware configured.")
# Out:
# Hardware configured.

# %%
from Crypto.Cipher import AES

# Known NIST AES-128 test vector
#fixed_key = bytes.fromhex("2b7e151628aed2a6abf7158809cf4f3c")
#fixed_text  = bytes.fromhex("5c692f9103b2302914d7e555e4dcee49")
fixed_text = bytes.fromhex("5C 69 2F 91 03 B2 30 29 14 D7 E5 55 E4 DC EE 49")
fixed_key = bytes.fromhex("2B 7E 15 16 28 AE D2 A6 AB F7 15 88 09 CF 4F 3C")
# Expected ciphertext
expected_output1 = AES.new(fixed_key, AES.MODE_ECB).encrypt(fixed_text)
expected_output = expected_output1.hex()
print("Expected CT:", expected_output1.hex())
# Out:
# Expected CT: 06f36a65e8a99ff8907b2e5e5ddd77de

# %%
from tqdm import notebook

# Constants from your script
#fixed_text = bytearray.fromhex("5C 69 2F 91 03 B2 30 29 14 D7 E5 55 E4 DC EE 49")
#fixed_key = bytearray.fromhex("2B 7E 15 16 28 AE D2 A6 AB F7 15 88 09 CF 4F 3C")
#expected_output = "06f36a65e8a99ff8907b2e5e5ddd77de"

# Define your scan ranges (Start, Stop, Step)
import numpy as np
widths = np.arange(0.390625, 49.0, 0.390625)
offsets = np.arange(-49.6094, 49.0, 0.390625)

target.set_key(fixed_key)

print("Starting Glitch Loop...")

for width in notebook.tqdm(widths, desc="Width"):
    for offset in offsets:
        scope.glitch.width = width
        scope.glitch.offset = offset
        
        scope.arm()
        
        # Write plaintext and wait for response
        target.simpleserial_write('p', fixed_text)
        
        ret = scope.capture()
        if ret:
            # print("Target timed out - might have crashed!")
            print(f"Timeout occurred on trace ")
            continue
            
        response = target.simpleserial_read('r', 16)
        
        # Check if response is valid/hex
        if response is None:
            continue
            
        res_hex = response.hex()
        
        # Logic to detect success
        if res_hex == expected_output:
            print(f"Normal! Width: {width}, Offset: {offset}")
            print(f"Result: {res_hex}")
        else:
            print(f"🌟 SUCCESS! Width: {width}, Offset: {offset}")
            print(f"Result: {res_hex}")
            # You can 'break' here if you only want the first successful glitch

#             # Log to CSV list
#             results_log.append({"width": width, "offset": offset, "result": status, "output": res_hex})
            
#             # Save to ChipWhisperer Project
#             project.traces.append(scope.get_last_trace(), data_in=fixed_text, data_out=response, key=fixed_key)


# # Save and Export
# project.save()

# df = pd.DataFrame(results_log)
# df.to_csv("glitch_results.csv", index=False)

# print("Done! Results saved to 'glitch_results.csv' and 'Glitch_Experiment_CW305.cwp'")
# Out:
# Starting Glitch Loop...
# Width:   0%|          | 0/125 [00:00<?, ?it/s]
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0f
# (ChipWhisperer Scope WARNING|File _OpenADCInterface.py:732) Timeout in OpenADC capture(), no trigger seen! Trigger forced, data is invalid. Status: 0e
# Timeout occurred on trace
# ---------------------------------------------------------------------------
# USBErrorIO                                Traceback (most recent call last)
# Cell In[4], line 33
#      30     print(f"Timeout occurred on trace ")
#      31     continue
# ---> 33 response = target.simpleserial_read('r', 16)
#      35 # Check if response is valid/hex
#      36 if response is None:
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\capture\targets\CW305.py:732, in CW305.simpleserial_read(self, cmd, pay_len, end, timeout, ack)
#     715 """Read data from target
#     716
#     717 Mimics simpleserial protocol of serial based targets
#    (...)    729     Added simpleserial_read to CW305
#     730 """
#     731 if cmd == "r":
# --> 732     return self.readOutput()
#     733 else:
#     734     raise ValueError("Unknown command {}".format(cmd))
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\capture\targets\CW305.py:648, in CW305.readOutput(self)
#     646     target_logger.error("target.REG_CRYPT_CIPHEROUT unset. Have you given target a verilog defines file?")
#     647     return
# --> 648 data = self.fpga_read(self.REG_CRYPT_CIPHEROUT, 16)
#     649 data = data[::-1]
#     650 #self.newInputData.emit(util.list2hexstr(data))
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\capture\targets\CW305.py:323, in CW305.fpga_read(self, addr, readlen)
#     321 addr = addr << self.bytecount_size
#     322 if self.platform in ['cw305', 'cw310', 'cw340']:
# --> 323     data = self._naeusb.cmdReadMem(addr, readlen)
#     324     return data
#     326 elif 'ss2' in self.platform:
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:889, in NAEUSB.cmdReadMem(self, addr, dlen)
#     883 def cmdReadMem(self, addr : int, dlen : int) -> bytearray:
#     884     """
#     885     Send command to read over external memory interface from FPGA. Automatically
#     886     decides to use control-transfer or bulk-endpoint transfer based on data length.
#     887     """
# --> 889     return self.usbserializer.cmdReadMem(addr, dlen)
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:635, in NAEUSB_Backend.cmdReadMem(self, addr, dlen)
#     633 dlen = int(dlen)
#     634 if dlen < NAEUSB_CTRL_IO_THRESHOLD:
# --> 635     data = self._cmd_readmem_ctrl(addr, dlen)
#     636 else:
#     637     data = self._cmd_readmem_bulk(addr, dlen)
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:616, in NAEUSB_Backend._cmd_readmem_ctrl(self, addr, dlen)
#     610 def _cmd_readmem_ctrl(self, addr : int, dlen : int):
#     611     """Reads data from the external memory interface over the control-transfer endpoint.
#     612
#     613     Returns:
#     614         The received data.
#     615     """
# --> 616     self._cmd_ctrl_send_header(addr, dlen, self.CMD_READMEM_CTRL);
#     617     return self.readCtrl(self.CMD_READMEM_CTRL, dlen=dlen)
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:608, in NAEUSB_Backend._cmd_ctrl_send_header(self, addr, dlen, cmd)
#     606 # TODO: Alloc header class member? Won't hafta alloc mem every read and writectrl call...
#     607 pload = make_len_addr(dlen, addr)
# --> 608 self._cmd_ctrl_send_data(pload, cmd)
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:597, in NAEUSB_Backend._cmd_ctrl_send_data(self, pload, cmd)
#     593 """Sends data over the control-transfer channel and attempts a pipe error fix if an initial
#     594 error occured.
#     595 """
#     596 try:
# --> 597     self.sendCtrl(cmd, data=pload)
#     598 except usb1.USBErrorPipe:
#     599     naeusb_logger.info("Attempting pipe error fix - typically safe to ignore")
#
# File ~\ChipWhisperer\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:551, in NAEUSB_Backend.sendCtrl(self, cmd, value, data)
#     549 if len(data) > NAEUSB_CTRL_IO_MAX:
#     550     naeusb_logger.error("The naeusb fw ctrl buffer is 128 bytes, but len(data) > 128. If you get a pipe error, this is why.")
# --> 551 self.handle.controlWrite(0x41, cmd, value, 0, data, timeout=self._timeout)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\usb1\__init__.py:1406, in USBDeviceHandle.controlWrite(self, request_type, request, value, index, data, timeout)
#    1404 # pylint: enable=undefined-variable
#    1405 data, _ = create_initialised_buffer(data)
# -> 1406 return self._controlTransfer(request_type, request, value, index, data,
#    1407                              sizeof(data), timeout)
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\usb1\__init__.py:1383, in USBDeviceHandle._controlTransfer(self, request_type, request, value, index, data, length, timeout)
#    1377 def _controlTransfer(
#    1378         self, request_type, request, value, index, data, length, timeout):
#    1379     result = libusb1.libusb_control_transfer(
#    1380         self.__handle, request_type, request, value, index, data, length,
#    1381         timeout,
#    1382     )
# -> 1383     mayRaiseUSBError(result)
#    1384     return result
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\usb1\__init__.py:129, in mayRaiseUSBError(value, __raiseUSBError)
#     123 def mayRaiseUSBError(
#     124         value,
#     125         # Avoid globals lookup on call to work during interpreter shutdown.
#     126         __raiseUSBError=raiseUSBError,
#     127     ):
#     128     if value < 0:
# --> 129         __raiseUSBError(value)
#     130     return value
#
# File ~\ChipWhisperer\cwenv\Lib\site-packages\usb1\__init__.py:121, in raiseUSBError(value, __STATUS_TO_EXCEPTION_DICT, __USBError)
#     115 def raiseUSBError(
#     116         value,
#     117         # Avoid globals lookup on call to work during interpreter shutdown.
#     118         __STATUS_TO_EXCEPTION_DICT=STATUS_TO_EXCEPTION_DICT,
#     119         __USBError=USBError,
#     120     ): # pylint: disable=dangerous-default-value
# --> 121     raise __STATUS_TO_EXCEPTION_DICT.get(value, __USBError)(value)
#
# USBErrorIO: LIBUSB_ERROR_IO [-1]

# %%
from tqdm import notebook # For a nice progress bar

# Define ranges
widths = [0.390625 + i*0.390625 for i in range(100)] # Example range
offsets = [-14.6094 + i*0.390625 for i in range(50)]

for width in notebook.tqdm(widths):
    for offset in offsets:
        scope.glitch.width = width
        scope.glitch.offset = offset
        
        # Arm scope and send plaintext
        scope.arm()
        target.simpleserial_write('p', bytearray([0x5C, 0x69...])) # Your fixed plaintext
        
        ret = scope.capture()
        if ret: continue # Skip if timeout
        
        output = target.simpleserial_read('r', 16)
        # Check for glitch success here

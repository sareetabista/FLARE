# %%
import chipwhisperer as cw
import os, time

# (Assuming scope and target are already connected)
#bitstream_path =  r'C:\Users\sbista\ChipWhisperer\chipwhisperer\firmware\fpgas\aes\vivado_\cw305_aes.runs\impl_100t\cw305_top.bit'
bitstream_path =  r'/home/sareeta/chipwhisperer/firmware/fpgas/aes/vivado_protected/cw305_aes.runs/impl_100t/cw305_top.bit'
assert os.path.isfile(bitstream_path), f"Bitstream not found: {bitstream_path}"

# 2) Connect to the capture board (CWLite)
scope = cw.scope()
scope.default_setup()

# 3) Connect and Program the FPGA
print("Programming CW305 FPGA with:", bitstream_path)
target = cw.target(scope, cw.targets.CW305, bsfile=bitstream_path, force=True)
#scope.dis()
# Out:
# ---------------------------------------------------------------------------
# USBErrorIO                                Traceback (most recent call last)
# Cell In[1], line 10
#       7 assert os.path.isfile(bitstream_path), f"Bitstream not found: {bitstream_path}"
#       9 # 2) Connect to the capture board (CWLite)
# ---> 10 scope = cw.scope()
#      11 scope.default_setup()
#      13 # 3) Connect and Program the FPGA
#
# File ~/chipwhisperer/software/chipwhisperer/__init__.py:400, in scope(scope_type, name, sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     398 rtn : scopes.ScopeTypes = scope_type()
#     399 try:
# --> 400     rtn.con(**kwargs)
#     401 except IOError:
#     402     scope_logger.error("ChipWhisperer error state detected. Resetting and retrying connection...")
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/OpenADC.py:709, in OpenADC.con(self, sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     706 self.gain = GainSettings(self.sc, self.adc)
#     708 self.pll = None
# --> 709 self.advancedSettings = ChipWhispererExtra.ChipWhispererExtra(cwtype, self.scopetype, self.sc)
#     710 self.glitch_drp1 = None
#     711 self.glitch_drp2 = None
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/cwhardware/ChipWhispererExtra.py:2306, in ChipWhispererExtra.__init__(self, cwtype, scope, oa)
#    2304 self.enableGlitch = True
#    2305 if self.enableGlitch:
# -> 2306     self.glitch = ChipWhispererGlitch.ChipWhispererGlitch(cwtype, scope, oa)
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/cwhardware/ChipWhispererGlitch.py:770, in ChipWhispererGlitch.__init__(self, cwtype, scope, oa)
#     767     self._max_offset = self.glitchPR.limitList[1][1] / 2.55
#     769 if not self._is_husky:
# --> 770     self.setOpenADC(oa)
#     771 self.glitchSettings = GlitchSettings(self)
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/cwhardware/ChipWhispererGlitch.py:785, in ChipWhispererGlitch.setOpenADC(self, oa)
#     782         return
#     784     # Reset FPGA back to defaults in case previous bitstreams loaded
# --> 785     self.updatePartialReconfig()
#     786 self.oa = oa
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/cwhardware/ChipWhispererGlitch.py:806, in ChipWhispererGlitch.updatePartialReconfig(self, _)
#     803 bs = self.glitchPR.getPartialBitstream([self._width, self._offset])
#     805 if self.prEnabled:
# --> 806     self.prCon.program(bs)
#     807     if self.oa is not None:
#     808         self.resetDCMs()
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/cwhardware/PartialReconfiguration.py:167, in PartialReconfigConnection.program(self, cfgdata)
#     163     dataarray.append(msb)
#     164     dataarray.append(lsb)
# --> 167 self.oa.sendMessage(self.CODE_WRITE, self.reconfig, dataarray, Validate=False)
#     169 # stat = self.oa.sendMessage(self.CODE_READ, self.reconfig, Validate=False, maxResp=1)
#     170 # print "%02x" % stat[0]
#     171
#     172 # Write Data
#     173 self.oa.sendMessage(self.CODE_WRITE, self.reconfig, [0x1A], Validate=False)
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:291, in OpenADCInterface.sendMessage(self, mode, address, payload, Validate, maxResp, readMask)
#     289 if mode != CODE_WRITE:
#     290     return self.msg_read(address, maxResp)
# --> 291 self.msg_write(address, payload)
#     292 if Validate:
#     293     self.msg_validate(address, payload, read_mask=readMask)
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:247, in OpenADCInterface.msg_write(self, address, payload)
#     244 address = self._address_str2int(address)
#     245 if self._serial_not_stream:
#     246     # Write output to memory
# --> 247     self.serial.cmdWriteMem(address, payload)
#     248 else:
#     249     self._send_msg_hdr(CODE_WRITE, address, len(payload))
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:897, in NAEUSB.cmdWriteMem(self, addr, data)
#     891 def cmdWriteMem(self, addr : int, data : bytearray):
#     892     """
#     893     Send command to write memory over external memory interface to FPGA. Automatically
#     894     decides to use control-transfer or bulk-endpoint transfer based on data length.
#     895     """
# --> 897     return self.usbserializer.cmdWriteMem(addr, data)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:668, in NAEUSB_Backend.cmdWriteMem(self, addr, data)
#     666     self._cmd_writemem_ctrl(addr, pload)
#     667 else:
# --> 668     self._cmd_writemem_bulk(addr, pload)
#     670 naeusb_logger.debug("FPGA_WRITE: bulk: {}, addr: {:08X}, dlen: {:08X}, response: {}"\
#     671     .format("yes" if len(pload) >= NAEUSB_CTRL_IO_THRESHOLD else "no", addr, len(pload), data))
#     673 return None
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:657, in NAEUSB_Backend._cmd_writemem_bulk(self, addr, data)
#     654 """Writes data to the external memory interface via the bulk-transfer endpoint.
#     655 """
#     656 self._cmd_ctrl_send_header(addr, len(data), self.CMD_WRITEMEM_BULK)
# --> 657 self._bulk_write(data, None)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:590, in NAEUSB_Backend._bulk_write(self, data, timeout)
#     587 """Writes data over the bulk-transfer endpoint.
#     588 """
#     589 timeout = self._get_timeout(timeout)
# --> 590 self.handle.bulkWrite(self.wep, data, timeout)
#
# File ~/.cwvenv/lib/python3.12/site-packages/usb1/__init__.py:1389, in USBDeviceHandle.bulkWrite(self, endpoint, data, timeout)
#    1387 # pylint: enable=undefined-variable
#    1388 data, _ = create_initialised_buffer(data)
# -> 1389 return self._bulkTransfer(endpoint, data, sizeof(data), timeout)
#
# File ~/.cwvenv/lib/python3.12/site-packages/usb1/__init__.py:1358, in USBDeviceHandle._bulkTransfer(self, endpoint, data, length, timeout)
#    1356 transferred = c_int()
#    1357 try:
# -> 1358     mayRaiseUSBError(libusb1.libusb_bulk_transfer(
#    1359         self.__handle, endpoint, data, length, byref(transferred), timeout,
#    1360     ))
#    1361 # pylint: disable=undefined-variable
#    1362 except USBErrorTimeout as exception:
#    1363     # pylint: enable=undefined-variable
#
# File ~/.cwvenv/lib/python3.12/site-packages/usb1/__init__.py:127, in mayRaiseUSBError(value, __raiseUSBError)
#     121 def mayRaiseUSBError(
#     122         value,
#     123         # Avoid globals lookup on call to work during interpreter shutdown.
#     124         __raiseUSBError=raiseUSBError,
#     125     ):
#     126     if value < 0:
# --> 127         __raiseUSBError(value)
#     128     return value
#
# File ~/.cwvenv/lib/python3.12/site-packages/usb1/__init__.py:119, in raiseUSBError(value, __STATUS_TO_EXCEPTION_DICT, __USBError)
#     113 def raiseUSBError(
#     114         value,
#     115         # Avoid globals lookup on call to work during interpreter shutdown.
#     116         __STATUS_TO_EXCEPTION_DICT=STATUS_TO_EXCEPTION_DICT,
#     117         __USBError=USBError,
#     118     ): # pylint: disable=dangerous-default-value
# --> 119     raise __STATUS_TO_EXCEPTION_DICT.get(value, __USBError)(value)
#
# USBErrorIO: LIBUSB_ERROR_IO [-1]

# %%
from Crypto.Cipher import AES
import os, time

key = bytes.fromhex("000102030405060708090a0b0c0d0e0f")
pt  = bytes.fromhex("00112233445566778899aabbccddeeff")

expected = AES.new(key, AES.MODE_ECB).encrypt(pt)

target.set_key(key)
target.loadInput(pt)
scope.arm()
target.go()
scope.capture()

ct = bytes(target.readOutput())

print("expected:", expected.hex())
print("actual:  ", ct.hex())
print("match:   ", ct == expected)

scope.dis()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 11
#       9 target.set_key(key)
#      10 target.loadInput(pt)
# ---> 11 scope.arm()
#      12 target.go()
#      13 scope.capture()
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/OpenADC.py:835, in OpenADC.arm(self)
#     824 """Setup scope to begin capture/glitching when triggered.
#     825
#     826 The scope must be armed before capture or glitching (when set to
#    (...)    832        disconnects before reraising them.
#     833 """
#     834 if self._is_connected is False:
# --> 835     raise OSError("Scope is not connected. Connect it first...")
#     836 if self._is_husky:
#     837     if self.XADC.status != 'good' and any(m in self.trigger.module for m in ['SAD', 'trace', 'UART']):
#
# OSError: Scope is not connected. Connect it first...

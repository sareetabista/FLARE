# %%
import chipwhisperer as cw
import chipwhisperer.common.results.glitch as glitch
import numpy as np
import time

# --- USER CONFIGURATION ---
# *** IMPORTANT:BITSTREAM PATH ***
BITSTREAM_FILEPATH = r'C:\Users\sbista\ChipWhisperer\chipwhisperer\firmware\fpgas\aes\vivado\cw305_aes_yam.runs\impl_100t\cw305_top.bit'

# Set a fixed key and plaintext for consistent testing
KEY = bytearray([0x2B, 0x7E, 0x15, 0x16, 0x28, 0xAE, 0xD2, 0xA6, 0xAB, 0xF7, 0x15, 0x88, 0x09, 0xCF, 0x4F, 0x3C])
PLAINTEXT = bytearray([0x5C, 0x69, 0x2F, 0x91, 0x03, 0xB2, 0x30, 0x29, 0x14, 0xD7, 0xE5, 0x55, 0xE4, 0xDC, 0xEE, 0x49])
EXPECTED_CIPHERTEXT = bytearray([0x06, 0xF3, 0x6A, 0x65, 0xE8, 0xA9, 0x9F, 0xF8, 0x90, 0x7B, 0x2E, 0x5E, 0x5D, 0xDD, 0x77, 0xDE])

NUM_GLITCH_ATTEMPTS = 500 # Number of times to try glitching
NUM_NORMAL_TRACES = 10000 # Number of traces without glitch for comparison

# --- CONNECTION ---
scope = cw.scope()
target = cw.target(scope, cw.targets.CW305, bsfile=BITSTREAM_FILEPATH, force=True)
# Out:
# (ChipWhisperer Target WARNING|File CW305.py:591) Using default Verilog defines (C:\Users\sbista\ChipWhisperer\chipwhisperer\software\chipwhisperer/hardware/firmware/cw305/cw305_aes_defines.v); if this is not what you want, provide them via the defines_files argument

# %%
#newone
scope.gain.gain = 40
scope.gain.mode = "high"
scope.adc.samples = 40
scope.adc.offset = 0
scope.adc.basic_mode = "rising_edge"
scope.clock.adc_src = "clkgen_x4"
scope.clock.freq_ctr_src = "clkgen"
scope.clock.adc_phase = 175
scope.trigger.triggers = "tio4"
scope.io.tio1 = "serial_rx"
scope.io.tio2 = "serial_tx"
scope.io.hs2 = "clkgen"

#CLKGEN Settings
scope.clock.extclk_freq = 10000000
scope.clock.clkgen_mul = 5
scope.clock.clkgen_div = 48
scope.clock.clkgen_freq = 10000000


import time
for i in range(5):
    scope.clock.reset_adc()
    time.sleep(1)
    if scope.clock.adc_locked:
        break 
assert (scope.clock.adc_locked), "ADC failed to lock"

# %%
#newone
scope.gain.gain = 40
scope.gain.mode = "high"
scope.adc.samples = 40
scope.adc.offset = 0
scope.adc.basic_mode = "rising_edge"
scope.clock.adc_src = "clkgen_x4"
scope.clock.freq_ctr_src = "clkgen"
scope.clock.adc_phase = 175
scope.trigger.triggers = "tio4"
scope.io.tio1 = "serial_tx"
scope.io.tio2 = "serial_rx"
scope.io.hs2 = "clkgen"

#CLKGEN Settings
scope.clock.extclk_freq = 10000000
scope.clock.clkgen_mul = 5
scope.clock.clkgen_div = 48
scope.clock.clkgen_freq = 10000000


import time
for i in range(5):
    scope.clock.reset_adc()
    time.sleep(1)
    if scope.clock.adc_locked:
        break 
assert (scope.clock.adc_locked), "ADC failed to lock"

# %%
target.set_key(KEY)
def run_aes(target, plaintext, KEY):
    target.simpleserial_write('p', plaintext)
    # The target.go() is handled by simpleserial_write for the CW305 target
    
    # Read the output from the target
    try:
        response = target.simpleserial_read('r', 16)
        if len(response) == 16:
            return response, True
        else:
            return None, False
    except Exception as e:
        print(f"Target read error: {e}")
        return None, False

# %%
for i in range(10):
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    
    if scope.capture():
        #print("Timeout – no trigger seen")
        continue


    if ok and out != EXPECTED_CIPHERTEXT:
        print("Not Normal:", out.hex())
    else:
        print("normal",out.hex())
# Out:
# Not Normal: 00000000000000000000000000000000
# Not Normal: 00000000000000000000000000000000
# Not Normal: 00000000000000000000000000000000
# Not Normal: 00000000000000000000000000000000
# Not Normal: 00000000000000000000000000000000
# Not Normal: 00000000000000000000000000000000
# Not Normal: 00000000000000000000000000000000
# Not Normal: 00000000000000000000000000000000
# Not Normal: 00000000000000000000000000000000
# Not Normal: 00000000000000000000000000000000

# %%
## --- 2. CAPTURE NORMAL TRACES ---
print("\n--- Collecting Normal Traces ---")
# Storage for the normal traces
normal_traces = []

#for i in range(NUM_NORMAL_TRACES):
for i in range(1000):
    scope.arm()
    output, success = run_aes(target, PLAINTEXT, KEY)
    
    if scope.capture():
        print(f"Timeout occurred on trace {i}")
        continue

    trace = scope.get_last_trace()
    normal_traces.append(trace)
    
    # Verify the output is the expected ciphertext
    #if output == EXPECTED_CIPHERTEXT:
        #print(f"Trace {i}: Success, Output: {output.hex()}")
    #else:
        #print(f"Trace {i}: FAIL, Output: {output.hex() if output else 'N/A'}")

    if output != EXPECTED_CIPHERTEXT:
        print(f"Trace {i}: FAIL, Output: {output.hex() if output else 'N/A'}")
        
print(f"Baseline trace collection complete. Collected {len(normal_traces)} good traces.")
# Out:
# --- Collecting Normal Traces ---
# Baseline trace collection complete. Collected 1000 good traces.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ensure your normal_traces list has data
if not normal_traces:
    print("Error: No traces were collected. Run the 'Normal Trace Collection' loop first.")
else:
    # --- PLOT SETUP ---
    
    # 1. Get the first trace as a baseline
    first_trace = np.array(normal_traces[0])
    
    # 2. Get the average of all collected traces (provides a cleaner view)
    average_trace = np.average(normal_traces, axis=0)
    
    # --- PLOTTING ---
    plt.figure(figsize=(12, 6))
    
    # Plot the first collected trace
    plt.plot(first_trace, label="Single Trace (Trace 0)", color='red', alpha=0.5,linewidth=1)
    
    # Plot the average trace
    plt.plot(average_trace, label=f"Average of {len(normal_traces)} Traces", color='blue', linewidth=1)
    
    plt.title("Baseline Power Trace: AES on CW305 FPGA")
    plt.xlabel("Sample Number")
    plt.ylabel("Power Consumption (ADC Units)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
#Glitch Setup 
scope.io.hs2 = "glitch"
scope.glitch.clk_src = 'clkgen'
scope.glitch.ext_offset = 0
scope.glitch.width = 5.078125
scope.glitch.offset = -1.953125
scope.glitch.trigger_src = "continuous" #change this depending on glitching desired
#target.api.setParameter(['Glitch Module', 'Output Mode', 'Clock XORd'])

# %%
for i in range(10):
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    
    if scope.capture():
        print("Timeout – no trigger seen")
        continue


    if ok and out != EXPECTED_CIPHERTEXT:
        print("REAL GLITCH FAULT FOUND:", out.hex())
    else:
        print("normal",out.hex())
# Out:
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de

# %%
## --- 2. CAPTURE Glitched TRACES ---
print("\n--- Collecting Traces after introducing Faults---")
# Storage for the normal traces
glitched_traces = []

for i in range(NUM_NORMAL_TRACES):
    scope.arm()
    output, success = run_aes(target, PLAINTEXT, KEY)
    
    if scope.capture():
        print(f"Timeout occurred on trace {i}")
        continue

    trace = scope.get_last_trace()
    glitched_traces.append(trace)
    
    # Verify the output is the expected ciphertext
    #if output == EXPECTED_CIPHERTEXT:
        #print(f"Trace {i}: Success, Output: {output.hex()}")
    #else:
        #print(f"Trace {i}: FAIL, Output: {output.hex() if output else 'N/A'}")

    if output != EXPECTED_CIPHERTEXT:
        print(f"Trace {i}: FAIL, Output: {output.hex() if output else 'N/A'}")
        
print(f"After glitching trace collection complete. Collected {len(glitched_traces)} After Glitching traces.")
# Out:
# --- Collecting Traces after introducing faults---
# Trace 5: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 54: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 63: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 66: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 69: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 76: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 91: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 96: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 104: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 132: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 150: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 178: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 193: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 207: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 214: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 230: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 233: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 267: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 271: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 325: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 354: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 365: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 370: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 383: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 385: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 398: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 417: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 421: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 442: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 482: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 509: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 533: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 562: FAIL, Output: db53f0d1caaaca18a649fddce6266978
# Trace 598: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 616: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 618: FAIL, Output: db53f0d1caaaca18a649fddce6266978
# Trace 622: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 639: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 648: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 682: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 703: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 734: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 778: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 782: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 790: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 804: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 814: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 817: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 828: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 835: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 864: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 883: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 884: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 900: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 918: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 947: FAIL, Output: db53f0d1caaaca18a649fddce6266978
# Trace 987: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 990: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 1022: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1050: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1054: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 1057: FAIL, Output: d78b755607010767e09885de8d8f977c
# Trace 1079: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 1094: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 1102: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1115: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 1121: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 1129: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1146: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1183: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1191: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 1195: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1204: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1215: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1237: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1270: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1279: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 1290: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1295: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 1315: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1316: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1335: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1341: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1342: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 1357: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1380: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1384: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1393: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1406: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1417: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1418: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1439: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1474: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1475: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1480: FAIL, Output: d78b755607010767e09885de8d8f977c
# Trace 1481: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 1491: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1546: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 1611: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1650: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1673: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 1689: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 1697: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1701: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1706: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 1716: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1727: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 1757: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1827: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 1845: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 1856: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1902: FAIL, Output: e6117dfe9378c61bca9f00af8a310ac2
# Trace 1912: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 1933: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 1983: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 1998: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 2004: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2018: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 2038: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 2048: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2074: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 2096: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 2123: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 2126: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2129: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2162: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2210: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2252: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2259: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2262: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2269: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2286: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2337: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2339: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2355: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2365: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2377: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2397: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 2407: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 2457: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2486: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2526: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 2555: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 2556: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 2563: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2688: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 2692: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2695: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2698: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 2701: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2715: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 2728: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 2777: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 2808: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 2837: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 2860: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 2968: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 2977: FAIL, Output: db53f0d1caaaca18a649fddce6266978
# Trace 2989: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3061: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3087: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3092: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3098: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3113: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3132: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3148: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3150: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3211: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3212: FAIL, Output: cbf9b008352ffbc7a72dda7c6139bab6
# Trace 3246: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 3250: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3257: FAIL, Output: d78b755607010767e09885de8d8f977c
# Trace 3300: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3322: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 3334: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3335: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 3377: FAIL, Output: 67d51e5da5410887e67d158a6329753e
# Trace 3407: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3458: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3530: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 3540: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3553: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3563: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 3608: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3651: FAIL, Output: b6b712de6838f0ecf8eb52101065a94d
# Trace 3654: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3665: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 3720: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 3729: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 3733: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 3793: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3815: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3817: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3824: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3883: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3889: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 3898: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 3905: FAIL, Output: d78b755607010767e09885de8d8f977c
# Trace 3908: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 3914: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3940: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 3990: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 3995: FAIL, Output: db53f0d1caaaca18a649fddce6266978
# Trace 4004: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4049: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 4083: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4091: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 4146: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4162: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 4168: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4191: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 4211: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4237: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 4259: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4285: FAIL, Output: d8fd8c30c419f6746c34cd7d0cd4a813
# Trace 4300: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 4316: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 4336: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4337: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4338: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4362: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 4406: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 4413: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4424: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 4459: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4482: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4503: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 4529: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 4539: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4549: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 4562: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 4582: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4599: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4655: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4705: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 4820: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 4868: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4869: FAIL, Output: d78b755607010767e09885de8d8f977c
# Trace 4884: FAIL, Output: 309ea7d317ac72a59cee413031ecd67b
# Trace 4893: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 4910: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 4938: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 4963: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 5005: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5013: FAIL, Output: a743f016e3ad749dba774dd9ca3b5503
# Trace 5014: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5035: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5058: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5060: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5064: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 5069: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5179: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5189: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 5191: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5197: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5207: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5235: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 5251: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 5357: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5371: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5387: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5392: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 5394: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5450: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5457: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5460: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5463: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5469: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5513: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5525: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5565: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5588: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 5593: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5612: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5621: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5639: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5641: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 5654: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5660: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5669: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5679: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 5683: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5698: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 5716: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5720: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5755: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 5787: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5828: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 5857: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 5864: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5865: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5906: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5919: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 5930: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5964: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5969: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5979: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 5990: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 5997: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6000: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 6002: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6014: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 6020: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6055: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6058: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6082: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6087: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6110: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6136: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6140: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6159: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6165: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6182: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6184: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6221: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6254: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 6258: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6277: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6279: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6284: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6305: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6306: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6341: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 6347: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 6387: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6410: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6443: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6446: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6520: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6558: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6604: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6606: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6622: FAIL, Output: db53f0d1caaaca18a649fddce6266978
# Trace 6639: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6655: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6682: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 6687: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6704: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6749: FAIL, Output: d78b755607010767e09885de8d8f977c
# Trace 6815: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6830: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6854: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6900: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6913: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 6919: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 6944: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6959: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 6969: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 7002: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7017: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 7022: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7035: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 7040: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7080: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7089: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7118: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7126: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7139: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7150: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 7159: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7203: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7204: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7215: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 7249: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7257: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7271: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 7275: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 7300: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7309: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 7310: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7313: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7328: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7381: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 7405: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 7438: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 7525: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 7534: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7573: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7593: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7604: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7671: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 7714: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7730: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 7735: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7747: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 7767: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 7775: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7806: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7820: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 7841: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7880: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7908: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 7935: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 7976: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8056: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8073: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8079: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 8103: FAIL, Output: d78b755607010767e09885de8d8f977c
# Trace 8128: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8140: FAIL, Output: d78b755607010767e09885de8d8f977c
# Trace 8161: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 8206: FAIL, Output: db53f0d1caaaca18a649fddce6266978
# Trace 8210: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8220: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8227: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8277: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8286: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8301: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 8310: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8317: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8324: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8330: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8407: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8457: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8462: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8467: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8475: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8539: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8566: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8586: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8667: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8721: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8741: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 8751: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8771: FAIL, Output: 40a86bb484e5d7567542fa7caf8ee892
# Trace 8787: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8791: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8801: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8818: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8838: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8839: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8880: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8926: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8939: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 8943: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 8963: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9015: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 9035: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9054: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9092: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9094: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 9136: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9144: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9151: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 9152: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9175: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9204: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 9236: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9247: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9248: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 9251: FAIL, Output: d78b755607010767e09885de8d8f977c
# Trace 9269: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9275: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 9341: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9372: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9377: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 9378: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9400: FAIL, Output: 73a145d7659d82c950116be72c232e78
# Trace 9402: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9437: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 9455: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9476: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9501: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9503: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9574: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9597: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9609: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9688: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 9694: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 9717: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9721: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9741: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9770: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9776: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9799: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9812: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9832: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9854: FAIL, Output: 743a9532fd3deedb0f3e6b1d3758ba0b
# Trace 9895: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9901: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9927: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9932: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9935: FAIL, Output: 7127cb392a46704f9e279aac1c368009
# Trace 9945: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# Trace 9975: FAIL, Output: c8a23859eb5672ad5965e0e67ec0f658
# Trace 9978: FAIL, Output: 9d60e893cd036b4f57a520917c762ada
# After glitching trace collection complete. Collected 10000 After Glitching traces.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ensure your normal_traces list has data
if not glitched_traces:
    print("Error: No traces were collected. Run the 'Glitched Trace Collection' loop first.")
else:
    # --- PLOT SETUP ---
    
    # 1. Get the first trace as a baseline
    first_trace = np.array(glitched_traces[0])
    
    # 2. Get the average of all collected traces (provides a cleaner view)
    average_trace = np.average(glitched_traces, axis=0)
    
    # --- PLOTTING ---
    plt.figure(figsize=(12, 6))
    
    # Plot the first collected trace
    plt.plot(first_trace, label="Single Trace (Trace 0)", color='red', alpha=0.5,linewidth=1)
    
    # Plot the average trace
    plt.plot(average_trace, label=f"Average of {len(glitched_traces)} Traces", color='blue', linewidth=1)
    
    plt.title("Baseline Power Trace: AES on CW305 FPGA after glitching")
    plt.xlabel("Sample Number")
    plt.ylabel("Power Consumption (ADC Units)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
def diff_bytes(a, b):
    return sum(x != y for x, y in zip(a, b))
N = 10000
faults = 0
hist = {}
for i in range(N):
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    if scope.capture() or (not ok) or out is None:
        continue

    d = diff_bytes(out, EXPECTED_CIPHERTEXT)
    hist[d] = hist.get(d, 0) + 1
    if d != 0:
        faults += 1
print("Fault rate:", faults / N)
print("Diff-bytes histogram:", dict(sorted(hist.items())))
# Out:
# Fault rate: 0.0278
# Diff-bytes histogram: {0: 9722, 6: 1, 16: 277}

# %%
from collections import Counter

pos_ctr = Counter()

for i in range(N):
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    if scope.capture() or (not ok) or out is None:
        continue
    if out == EXPECTED_CIPHERTEXT:
        continue
    for idx, (a,b) in enumerate(zip(out, EXPECTED_CIPHERTEXT)):
        if a != b:
            pos_ctr[idx] += 1

print("Byte position fault counts (0..15):")
print(dict(sorted(pos_ctr.items())))
# Out:
# Byte position fault counts (0..15):
# {0: 364, 1: 364, 2: 364, 3: 364, 4: 364, 5: 364, 6: 364, 7: 364, 8: 364, 9: 364, 10: 364, 11: 364, 12: 364, 13: 364, 14: 364, 15: 364}

# %%
def run_aes(target, plaintext, key):
    target.set_key(key)
    target.simpleserial_write('p', plaintext)
    # The target.go() is handled by simpleserial_write for the CW305 target
    
    # Read the output from the target
    try:
        response = target.simpleserial_read('r', 16)
        if len(response) == 16:
            return response, True
        else:
            return None, False
    except Exception as e:
        print(f"Target read error: {e}")
        return None, False

# %%
print(f"Target VCC-INT set to: {target.vccint_get()}V")

# Setup PLL1 on CW305 (assuming 10MHz external clock is provided by CW-Lite)
target.pll.pll_outfreq_set(10E6, 1) # Set PLL1 to 50 MHz (common FPGA clock)
target.pll.pll_enable_set(True)
target.pll.pll_outenable_set(True, 1)

# --- CONFIGURE CW-LITE SCOPE FOR POWER TRACING ---
# Use the clock generated by the CW305 (EXTCLK) as the ADC clock source
scope.default_setup()
scope.clock.adc_src = "extclk_x4" # Use 4x the target clock for sampling
scope.adc.samples = 400 # Number of samples to capture per trace
scope.adc.offset = 0
scope.gain.gain = 25
scope.adc.presamples = 0
scope.adc.basic_mode = "falling_edge"
scope.trigger.triggers = 'tio4' # FPGA trigger pin TIO4 is used to arm the scope/glitch
scope.io.tio1 = "serial_tx"
scope.io.tio2 = "serial_rx"
scope.io.tio3 = "high_z" # Not used
scope.io.tio4 = "high_z" # Used for trigger, set by FPGA





import time
for i in range(5):
    scope.clock.reset_adc()
    time.sleep(1)
    if scope.clock.adc_locked:
        break 
assert (scope.clock.adc_locked), "ADC failed to lock"
# Out:
# Target VCC-INT set to: 1.0V
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 30
# scope.gain.db                            changed from 5.5                       to 24.8359375
# scope.adc.basic_mode                     changed from low                       to rising_edge
# scope.adc.samples                        changed from 24400                     to 5000
# scope.adc.trig_count                     changed from 2519970607                to 2532971202
# scope.clock.adc_src                      changed from clkgen_x1                 to clkgen_x4
# scope.clock.adc_freq                     changed from 96000000                  to 29538459
# scope.clock.adc_rate                     changed from 96000000.0                to 29538459.0
# scope.clock.freq_ctr                     changed from 10000385                  to 10000396
# scope.clock.clkgen_div                   changed from 1                         to 26
# scope.clock.clkgen_freq                  changed from 192000000.0               to 7384615.384615385
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen
# scope.io.tio_states                      changed from (1, 0, 0, 0)              to (0, 1, 0, 0)

# %%
#scope.io.glitch_lp = False     # CW305 uses LP glitch
#scope.io.glitch_hp = False
for i in range(10):
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    
    if scope.capture():
        print("Timeout – no trigger seen")
        continue


    if ok and out != EXPECTED_CIPHERTEXT:
        print("REAL GLITCH FAULT FOUND:", out.hex())
        break
    else:
        print("normal",out.hex())
# Out:
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de

# %%
## --- 2. CAPTURE NORMAL TRACES ---
print("\n--- Collecting Normal Traces ---")
# Storage for the normal traces
normal_traces = []

# Function to run the AES encryption on the target
def run_aes(target, plaintext, key):
    target.set_key(key)
    target.simpleserial_write('p', plaintext)
    # The target.go() is handled by simpleserial_write for the CW305 target
    
    # Read the output from the target
    try:
        response = target.simpleserial_read('r', 16)
        if len(response) == 16:
            return response, True
        else:
            return None, False
    except Exception as e:
        print(f"Target read error: {e}")
        return None, False

for i in range(NUM_NORMAL_TRACES):
    scope.arm()
    output, success = run_aes(target, PLAINTEXT, KEY)
    
    if scope.capture():
        print(f"Timeout occurred on trace {i}")
        continue

    trace = scope.get_last_trace()
    normal_traces.append(trace)
    
    # Verify the output is the expected ciphertext
    #if output == EXPECTED_CIPHERTEXT:
        #print(f"Trace {i}: Success, Output: {output.hex()}")
    #else:
        #print(f"Trace {i}: FAIL, Output: {output.hex() if output else 'N/A'}")

    if output != EXPECTED_CIPHERTEXT:
        print(f"Trace {i}: FAIL, Output: {output.hex() if output else 'N/A'}")
        
print(f"Baseline trace collection complete. Collected {len(normal_traces)} good traces.")
# Out:
# --- Collecting Normal Traces ---
# Baseline trace collection complete. Collected 10000 good traces.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ensure your normal_traces list has data
if not normal_traces:
    print("Error: No traces were collected. Run the 'Normal Trace Collection' loop first.")
else:
    # --- PLOT SETUP ---
    
    # 1. Get the first trace as a baseline
    first_trace = np.array(normal_traces[0])
    
    # 2. Get the average of all collected traces (provides a cleaner view)
    average_trace = np.average(normal_traces, axis=0)
    
    # --- PLOTTING ---
    plt.figure(figsize=(12, 6))
    
    # Plot the first collected trace
    plt.plot(first_trace, label="Single Trace (Trace 0)", color='red', alpha=0.5,linewidth=1)
    
    # Plot the average trace
    plt.plot(average_trace, label=f"Average of {len(normal_traces)} Traces", color='blue', linewidth=1)
    
    plt.title("Baseline Power Trace: AES on CW305 FPGA")
    plt.xlabel("Sample Number")
    plt.ylabel("Power Consumption (ADC Units)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
import time
import numpy as np
from collections import Counter

EXPECTED = bytes(EXPECTED_CIPHERTEXT)

def diff_bytes(a, b):
    return sum(x != y for x, y in zip(a, b))

def one_run():
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    if scope.capture() or (not ok) or out is None:
        return None
    return out

def eval_setting(trials=300):
    """Return: total, faults, fault_rate, avg_diff, top3_masks"""
    total = 0
    faults = 0
    diffs = []
    mask_ctr = Counter()

    for _ in range(trials):
        out = one_run()
        if out is None:
            continue
        total += 1
        d = diff_bytes(out, EXPECTED)
        diffs.append(d)
        if d != 0:
            faults += 1
            m = bytes([x ^ y for x, y in zip(out, EXPECTED)]).hex()
            mask_ctr[m] += 1

    if total == 0:
        return 0, 0, 0.0, 0.0, []
    return total, faults, faults/total, sum(diffs)/len(diffs), mask_ctr.most_common(3)

# %%
# Make sure baseline VCC is safe
target.vccint_set(1.0)
time.sleep(0.2)

# Enable voltage glitch path for CW305
scope.io.glitch_lp = True
scope.io.glitch_hp = False
scope.glitch.repeat = 1
scope.glitch.trigger_src = 'ext_single'

# %%
import numpy as np
import time
import csv
from collections import Counter

EXPECTED = bytes(EXPECTED_CIPHERTEXT)

def diff_bytes(a, b):
    return sum(x != y for x, y in zip(a, b))

def one_run():
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    if scope.capture() or (not ok) or out is None:
        return None
    return out

def eval_setting(trials=80):
    total = 0
    faults = 0
    diffs = []
    masks = Counter()

    for _ in range(trials):
        out = one_run()
        if out is None:
            continue
        total += 1
        d = diff_bytes(out, EXPECTED)
        diffs.append(d)
        if d != 0:
            faults += 1
            m = bytes([x ^ y for x, y in zip(out, EXPECTED)]).hex()
            masks[m] += 1

    if total == 0:
        return 0, 0.0, 0.0, 0, []
    fault_rate = faults / total
    avg_diff = sum(diffs) / len(diffs)
    unique_masks = len(masks)
    top3 = masks.most_common(3)
    return total, fault_rate, avg_diff, unique_masks, top3

# --- FULL RANGE SETTINGS ---
target.vccint_set(1.0)   # mapping at clean baseline
time.sleep(0.2)

scope.io.glitch_lp = True
scope.io.glitch_hp = False
scope.glitch.repeat = 1
scope.glitch.trigger_src = 'ext_single'

# Allowed offset range from hardware:
off_lo = scope.glitch.cwg._min_offset
off_hi = scope.glitch.cwg._max_offset

# Dense offsets (e.g., 81 points across full range)
offsets = np.linspace(-10, 40, 20)

# Dense widths: cover very small widths too (log spaced)
# Tune endpoints if needed; these are safe to try.
widths = np.geomspace(0.5, 40.0, 40)  # 40 widths from 0.001 to 1.0

# Optional: avoid exactly 0 offset if you get the warning
def sanitize_offset(x):
    return 0.5 if abs(x) < 1e-12 else float(x)

results = []
csv_path = "grid_sweep_results.csv"

print(f"Sweeping {len(widths)} widths × {len(offsets)} offsets = {len(widths)*len(offsets)} points")
print("Saving to:", csv_path)

with open(csv_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["width", "offset", "total", "fault_rate", "avg_diff", "unique_masks", "top1", "top1_count", "top2", "top2_count", "top3", "top3_count"])

    for wi, w in enumerate(widths):
        scope.glitch.width = float(w)
        time.sleep(0.01)

        for oi, off in enumerate(offsets):
            off = sanitize_offset(off)
            scope.glitch.offset = float(off)
            time.sleep(0.005)

            total, fr, avgd, uniq, top3 = eval_setting(trials=80)

            # pad top3
            padded = top3 + [("","")] * (3 - len(top3))
            (m1,c1),(m2,c2),(m3,c3) = padded[:3]

            writer.writerow([float(w), float(off), total, fr, avgd, uniq, m1, c1, m2, c2, m3, c3])
            f.flush()

            # console progress (light)
            if (oi % 20 == 0):
                print(f"w[{wi+1}/{len(widths)}]={w:.4f}  off={off:7.2f}  fr={fr:.2f}  avgd={avgd:.2f}  uniq={uniq}")

print("Done.")
# Out:
# Sweeping 40 widths × 20 offsets = 800 points
# Saving to: grid_sweep_results.csv
# w[1/40]=0.5000  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[2/40]=0.5595  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[3/40]=0.6260  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[4/40]=0.7004  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[5/40]=0.7837  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[6/40]=0.8769  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[7/40]=0.9812  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[8/40]=1.0979  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[9/40]=1.2284  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[10/40]=1.3745  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[11/40]=1.5379  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[12/40]=1.7208  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[13/40]=1.9255  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[14/40]=2.1544  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[15/40]=2.4106  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[16/40]=2.6973  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[17/40]=3.0180  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[18/40]=3.3769  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[19/40]=3.7785  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[20/40]=4.2278  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[21/40]=4.7306  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[22/40]=5.2931  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[23/40]=5.9225  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[24/40]=6.6268  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[25/40]=7.4148  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[26/40]=8.2966  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[27/40]=9.2832  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[28/40]=10.3871  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[29/40]=11.6223  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[30/40]=13.0043  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[31/40]=14.5507  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[32/40]=16.2811  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[33/40]=18.2171  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[34/40]=20.3834  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[35/40]=22.8073  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[36/40]=25.5194  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[37/40]=28.5541  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[38/40]=31.9496  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[39/40]=35.7489  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# w[40/40]=40.0000  off= -10.00  fr=0.00  avgd=0.00  uniq=0
# Done.

# %%
print(hasattr(scope.glitch, "ext_offset"))
print(scope.glitch)
print("offset:", scope.glitch.offset)
print("width:", scope.glitch.width)
# Out:
# True
# clk_src     = target
# mmcm_locked = True
# width       = 30.078125
# width_fine  = 0
# offset      = 39.84375
# offset_fine = 0
# trigger_src = ext_single
# arm_timing  = after_scope
# ext_offset  = 0
# repeat      = 1
# output      = clock_xor
#
# offset: 39.84375
# width: 30.078125

# %%
# Enable glitch path
scope.io.glitch_lp = True     # CW305 uses LP glitch
scope.io.glitch_hp = False

scope.glitch.repeat = 1
scope.glitch.trigger_src = 'ext_single'  # standard

scope.glitch.width  = 2.0     # small
scope.glitch.offset = 20.0    # early, but not extreme

for i in range(10):
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)

    if scope.capture():
        continue

    if ok and out != EXPECTED_CIPHERTEXT:
        print("REAL GLITCH FAULT FOUND:", out.hex())
        break
    else:
        print("normal",out.hex())
# Out:
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de

# %%
# Enable glitch path
scope.io.glitch_lp = True     # CW305 uses LP glitch
scope.io.glitch_hp = False
scope.glitch.repeat = 1
scope.glitch.trigger_src = 'ext_single'  # standard
scope.glitch.width  = 2.0
scope.glitch.offset = 20.0
for i in range(10):
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    
    if scope.capture():
        print("Timeout – no trigger seen")
        continue
    if ok and out != EXPECTED_CIPHERTEXT:
        print("REAL GLITCH FAULT FOUND:", out.hex())
    else:
        print("normal",out.hex())
# Out:
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de
# normal 06f36a65e8a99ff8907b2e5e5ddd77de

# %%
def diff_bytes(a, b):
    return sum(x != y for x, y in zip(a, b))
N = 1000
faults = 0
hist = {}
for i in range(N):
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    if scope.capture() or (not ok) or out is None:
        continue

    d = diff_bytes(out, EXPECTED_CIPHERTEXT)
    hist[d] = hist.get(d, 0) + 1
    if d != 0:
        faults += 1
print("Fault rate:", faults / N)
print("Diff-bytes histogram:", dict(sorted(hist.items())))
# Out:
# Fault rate: 0.0
# Diff-bytes histogram: {0: 1000}

# %%
from collections import Counter

pos_ctr = Counter()

for i in range(N):
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    if scope.capture() or (not ok) or out is None:
        continue
    if out == EXPECTED_CIPHERTEXT:
        continue
    for idx, (a,b) in enumerate(zip(out, EXPECTED_CIPHERTEXT)):
        if a != b:
            pos_ctr[idx] += 1

print("Byte position fault counts (0..15):")
print(dict(sorted(pos_ctr.items())))
# Out:
# Byte position fault counts (0..15):
# {0: 174, 1: 142, 2: 131, 3: 124, 4: 120, 5: 132, 6: 123, 7: 141, 9: 135, 10: 149, 11: 130, 12: 50, 13: 60, 14: 146, 15: 125}

# %%
mask_ctr = Counter()

for i in range(N):
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    if scope.capture() or (not ok) or out is None:
        continue
    if out == bytes(EXPECTED_CIPHERTEXT):
        continue
    masks = bytes([x ^ y for x,y in zip(out, EXPECTED_CIPHERTEXT)])
    mask_ctr[masks.hex()] += 1

print("Top 10 XOR masks:")
for m,c in mask_ctr.most_common(10):
    print(c, m)
# Out:
# Top 10 XOR masks:
# 113 00000000000000200000000000000000
# 66 02000000000000000023000000000000
# 60 00002200000000000000000200000000
# 59 00000000000003000000000000000000
# 50 00000000200000000000000000010002
# 40 02000000000000000000000000000000
# 35 00000000002100000000000000002300
# 34 00000020000000000000000001000000
# 30 00002200000000000000220000000000
# 28 00230000000000000000220000000000

# %%
for off in np.linspace(-40, 40, 90):
    scope.glitch.offset = off
    scope.arm()
    out, ok = run_aes(target, PLAINTEXT, KEY)
    scope.capture()
    if ok and out != EXPECTED_CIPHERTEXT:
        print("FAULT at offset", off, out.hex())

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ensure your normal_traces list has data
if not normal_traces:
    print("Error: No traces were collected. Run the 'Normal Trace Collection' loop first.")
else:
    # --- PLOT SETUP ---
    
    # 1. Get the first trace as a baseline
    first_trace = np.array(normal_traces[0])
    
    # 2. Get the average of all collected traces (provides a cleaner view)
    average_trace = np.average(normal_traces, axis=0)
    
    # --- PLOTTING ---
    plt.figure(figsize=(12, 6))
    
    # Plot the first collected trace
    plt.plot(first_trace, label="Single Trace (Trace 0)", color='red', alpha=0.5,linewidth=1)
    
    # Plot the average trace
    plt.plot(average_trace, label=f"Average of {len(normal_traces)} Traces", color='blue', linewidth=1)
    
    plt.title("Baseline Power Trace: AES on CW305 FPGA")
    plt.xlabel("Sample Number")
    plt.ylabel("Power Consumption (ADC Units)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
glitched_results = []
successful_faults = 0
successful_params = []
# --- VCC_INT SWEEP DEFINITION ---
# Start safe (1.0V) and go down to crash point (0.70V), in 10 steps
VCC_INT_TARGET = 1.0
# Sweep the range just before Round 10 to catch Round 9
OFFSETS = np.linspace(4.0, 49, 80) 

# Keep VCC very low as you've confirmed VCC=0.87 is effective
VCC_SWEEP = np.linspace(1.0, 0.87, 1)
FIXED_WIDTH = 4
ATTEMPTS_PER_POINT = 1

print("\n--- Starting Nested VCC/Offset Sweep ---")
print(f"Total Attempts: {len(VCC_SWEEP) * len(OFFSETS) * ATTEMPTS_PER_POINT}")


for vcc in VCC_SWEEP:
    # 1. SET THE NEW VULNERABLE VOLTAGE
    target.vccint_set(vcc)
    scope.glitch.width = FIXED_WIDTH
    
    # 2. SWEEP OFFSET AT THIS VOLTAGE LEVEL
    for offset in OFFSETS:
        scope.glitch.offset = offset
        
        # 3. ATTEMPT GLITCH MULTIPLE TIMES
        for attempt in range(ATTEMPTS_PER_POINT):
            
            i = len(glitched_results) # Tracking total attempts
            
            scope.arm()
            output, success = run_aes(target, PLAINTEXT, KEY)

            # --- CRASH & REPROGRAM LOGIC ---
            if scope.capture():
                # Handle timeout/crash
                try:
                    target.fpga_write(BITSTREAM_FILEPATH)
                except:
                    pass
                # Log the crash for plotting later
                glitched_results.append({'result': 'TIMEOUT', 'vcc': vcc, 'offset': offset})
                print(f"Attempt {i}: TIMEOUT (VCC={vcc:.2f}, o={offset:.1f}). Reprogrammed.")
                continue
            
            # --- FAULT DETECTION LOGIC ---
            output_hex = output.hex() if output else "N/A"
            expected_hex = EXPECTED_CIPHERTEXT.hex()
            
            if output_hex != expected_hex:
                result = 'FAULT'
                successful_faults += 1
            else:
                result = 'NORMAL'
                
            # Log the result
            glitched_results.append({'result': result, 'vcc': vcc, 'offset': offset, 'output': output_hex})
            
            # --- MODIFIED PRINT STATEMENT TO SHOW OUTPUT ---
            if result == 'FAULT':
                print(f"Attempt {i}: **FAULT** (VCC={vcc:.2f}, o={offset:.1f}) OUTPUT: {output_hex}")
                successful_params.append({'vcc': vcc, 'offset': offset, 'output': output_hex})
            else:
                # Prints the correct output for monitoring
                print(f"Attempt {i}: Normal (VCC={vcc:.2f}, o={offset:.1f}) OUTPUT: {output_hex}")
# Out:
# --- Starting Nested VCC/Offset Sweep ---
# Total Attempts: 80
# Attempt 0: Normal (VCC=1.00, o=4.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 1: Normal (VCC=1.00, o=4.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 2: Normal (VCC=1.00, o=5.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 3: Normal (VCC=1.00, o=5.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 4: Normal (VCC=1.00, o=6.3) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 5: Normal (VCC=1.00, o=6.8) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 6: Normal (VCC=1.00, o=7.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 7: Normal (VCC=1.00, o=8.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 8: Normal (VCC=1.00, o=8.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 9: Normal (VCC=1.00, o=9.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 10: Normal (VCC=1.00, o=9.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 11: Normal (VCC=1.00, o=10.3) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 12: Normal (VCC=1.00, o=10.8) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 13: Normal (VCC=1.00, o=11.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 14: Normal (VCC=1.00, o=12.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 15: Normal (VCC=1.00, o=12.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 16: Normal (VCC=1.00, o=13.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 17: Normal (VCC=1.00, o=13.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 18: Normal (VCC=1.00, o=14.3) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 19: Normal (VCC=1.00, o=14.8) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 20: Normal (VCC=1.00, o=15.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 21: Normal (VCC=1.00, o=16.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 22: Normal (VCC=1.00, o=16.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 23: Normal (VCC=1.00, o=17.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 24: Normal (VCC=1.00, o=17.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 25: Normal (VCC=1.00, o=18.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 26: Normal (VCC=1.00, o=18.8) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 27: Normal (VCC=1.00, o=19.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 28: Normal (VCC=1.00, o=19.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 29: Normal (VCC=1.00, o=20.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 30: Normal (VCC=1.00, o=21.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 31: Normal (VCC=1.00, o=21.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 32: Normal (VCC=1.00, o=22.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 33: Normal (VCC=1.00, o=22.8) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 34: Normal (VCC=1.00, o=23.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 35: Normal (VCC=1.00, o=23.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 36: Normal (VCC=1.00, o=24.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 37: Normal (VCC=1.00, o=25.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 38: Normal (VCC=1.00, o=25.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 39: Normal (VCC=1.00, o=26.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 40: Normal (VCC=1.00, o=26.8) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 41: Normal (VCC=1.00, o=27.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 42: Normal (VCC=1.00, o=27.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 43: Normal (VCC=1.00, o=28.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 44: Normal (VCC=1.00, o=29.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 45: Normal (VCC=1.00, o=29.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 46: Normal (VCC=1.00, o=30.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 47: Normal (VCC=1.00, o=30.8) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 48: Normal (VCC=1.00, o=31.3) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 49: Normal (VCC=1.00, o=31.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 50: Normal (VCC=1.00, o=32.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 51: Normal (VCC=1.00, o=33.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 52: Normal (VCC=1.00, o=33.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 53: Normal (VCC=1.00, o=34.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 54: Normal (VCC=1.00, o=34.8) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 55: Normal (VCC=1.00, o=35.3) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 56: Normal (VCC=1.00, o=35.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 57: Normal (VCC=1.00, o=36.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 58: Normal (VCC=1.00, o=37.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 59: Normal (VCC=1.00, o=37.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 60: Normal (VCC=1.00, o=38.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 61: Normal (VCC=1.00, o=38.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 62: Normal (VCC=1.00, o=39.3) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 63: Normal (VCC=1.00, o=39.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 64: Normal (VCC=1.00, o=40.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 65: Normal (VCC=1.00, o=41.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 66: Normal (VCC=1.00, o=41.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 67: Normal (VCC=1.00, o=42.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 68: Normal (VCC=1.00, o=42.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 69: Normal (VCC=1.00, o=43.3) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 70: Normal (VCC=1.00, o=43.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 71: Normal (VCC=1.00, o=44.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 72: Normal (VCC=1.00, o=45.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 73: Normal (VCC=1.00, o=45.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 74: Normal (VCC=1.00, o=46.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 75: Normal (VCC=1.00, o=46.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 76: Normal (VCC=1.00, o=47.3) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 77: Normal (VCC=1.00, o=47.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 78: Normal (VCC=1.00, o=48.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 79: Normal (VCC=1.00, o=49.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de

# %%
# --- FINALIZED SWEET SPOT PARAMETERS ---
VCC_FINAL = 0.87      # Stable fault voltage
OFFSET_FINAL = 38.9 # Offset that consistently yields the fault
WIDTH_FINAL = 4.0     # Finalized width

# --- INITIALIZE FOR SINGLE ATTEMPT ---
glitched_trace_for_plot = None
attempt_result = None

target.vccint_set(VCC_FINAL)
scope.glitch.width = WIDTH_FINAL
scope.glitch.offset = OFFSET_FINAL
scope.glitch.repeat = 1

print(f"\n--- COLLECTING SINGLE FAULT TRACE at VCC={VCC_FINAL}V, Offset={OFFSET_FINAL} ---")

# Run loop until a successful fault trace is collected (max 10 attempts for stability)
for i in range(10): 
    scope.arm()
    output, success = run_aes(target, PLAINTEXT, KEY)

    if scope.capture():
        # Handle crash (reprogram if needed)
        try:
            target.fpga_write(BITSTREAM_FILEPATH)
            print(f"Attempt {i}: TIMEOUT. Reprogrammed.")
        except:
            pass
        continue

    output_hex = output.hex()
    expected_hex = EXPECTED_CIPHERTEXT.hex()
    
    if output_hex != expected_hex and success:
        # A true fault occurred, and communication was successful
        glitched_trace_for_plot = scope.get_last_trace()
        attempt_result = output_hex
        print(f"SUCCESS: Fault Trace Collected. Output: {attempt_result}")
    else:
        # Normal run, not crash. Continue attempting.
        print(f"Attempt {i}: Normal result. Re-attempting fault...")
        
# Set VCC-INT back to a safe level immediately
target.vccint_set(1.0)
# Out:
# --- COLLECTING SINGLE FAULT TRACE at VCC=0.87V, Offset=38.9 ---
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99ff8907b2e5e5ddd77de
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99ff8907b2e5e5ddd77de
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99fd8907b2e5e5ddd77de
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99ff8907b2e5e5ddd77de
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99ff8907b2e5e5ddd77de
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99ff8907b2e5e5ddd77de
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99ff8907b2e5e5ddd77de
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99ff8907b2e5e5ddd77de
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99ff8907b2e5e5ddd77de
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99ff8907b2e5e5ddd77de

# %%
import csv
import time

EXPECTED = EXPECTED_CIPHERTEXT  # bytes length 16

def num_diff_bytes(a, b):
    return sum(x != y for x, y in zip(a, b))

def xor_mask(a, b):
    return bytes([x ^ y for x, y in zip(a, b)])

def collect_10000_for_vcc(vcc, offset, width, N=10000, csv_path="aes_faults.csv",
                          save_fault_traces=False, max_fault_traces=50):
    # Apply settings
    target.vccint_set(vcc)
    scope.glitch.width = width
    scope.glitch.offset = offset
    scope.glitch.repeat = 1

    time.sleep(0.1)  # let rail settle

    fault_traces = []
    faults = 0
    timeouts = 0

    with open(csv_path, "a", newline="") as f:
        w = csv.writer(f)

        # Write header if file is empty
        if f.tell() == 0:
            w.writerow([
                "vcc","trial","status","success","ciphertext_hex",
                "is_faulty","num_diff_bytes","xor_mask_hex"
            ])

        for i in range(N):
            scope.arm()
            output, success = run_aes(target, PLAINTEXT, KEY)

            if scope.capture():
                timeouts += 1
                # Keep this lightweight; reprogram only if you truly need to.
                # If reprogram is necessary in your setup, keep it here:
                try:
                    target.fpga_write(BITSTREAM_FILEPATH)
                except Exception:
                    pass

                w.writerow([vcc, i, "TIMEOUT", 0, "", 0, "", ""])
                continue

            # If run_aes failed at comms layer, log it distinctly
            if not success or output is None or len(output) != 16:
                w.writerow([vcc, i, "BAD_COMM", int(success), "", 0, "", ""])
                continue

            is_faulty = int(output != EXPECTED)
            ndiff = num_diff_bytes(EXPECTED, output) if is_faulty else 0
            xmask = xor_mask(EXPECTED, output).hex() if is_faulty else "00"*16

            if is_faulty:
                faults += 1
                if save_fault_traces and len(fault_traces) < max_fault_traces:
                    fault_traces.append(scope.get_last_trace())

            w.writerow([vcc, i, "OK", 1, output.hex(), is_faulty, ndiff, xmask])

            # Print only occasionally (every 500) so it doesn’t slow you down
            if (i+1) % 500 == 0:
                print(f"VCC={vcc:.2f} | {i+1}/{N} | faults={faults} | timeouts={timeouts}")

    # Return VCC to safe level
    target.vccint_set(1.0)

    print(f"\nDONE VCC={vcc:.2f}: faults={faults}, timeouts={timeouts}, saved_traces={len(fault_traces)}")
    return fault_traces

# %%
target.set_key(key)
def run_aes(target, plaintext, key):
    target.simpleserial_write('p', plaintext)
    # The target.go() is handled by simpleserial_write for the CW305 target
    
    # Read the output from the target
    try:
        response = target.simpleserial_read('r', 16)
        if len(response) == 16:
            return response, True
        else:
            return None, False
    except Exception as e:
        print(f"Target read error: {e}")
        return None, False

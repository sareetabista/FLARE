# %%
import chipwhisperer as cw
import chipwhisperer.common.results.glitch as glitch
import numpy as np
import time

# --- USER CONFIGURATION ---
# *** IMPORTANT:BITSTREAM PATH ***
BITSTREAM_FILEPATH = r'C:\Users\sbista\ChipWhisperer\chipwhisperer\firmware\fpgas\aes\vivado\cw305_aes.runs\impl_100t\cw305_top.bit'

# Set a fixed key and plaintext for consistent testing
KEY = bytearray([0x2B, 0x7E, 0x15, 0x16, 0x28, 0xAE, 0xD2, 0xA6, 0xAB, 0xF7, 0x15, 0x88, 0x09, 0xCF, 0x4F, 0x3C])
PLAINTEXT = bytearray([0x5C, 0x69, 0x2F, 0x91, 0x03, 0xB2, 0x30, 0x29, 0x14, 0xD7, 0xE5, 0x55, 0xE4, 0xDC, 0xEE, 0x49])
EXPECTED_CIPHERTEXT = bytearray([0x06, 0xF3, 0x6A, 0x65, 0xE8, 0xA9, 0x9F, 0xF8, 0x90, 0x7B, 0x2E, 0x5E, 0x5D, 0xDD, 0x77, 0xDE])

#         04f36a65e8a99ff8907b2e5e5ddd77de
#expected=06f36a65e8a99ff8907b2e5e5ddd77de
#outputou=06f36a65e8a99ff8907b2e5e5ddd77de
          #04f36a65e8a99fd8907b0e5e5ddd77de
#0.88targ=04f36a65e8a99ff8907b2e5e5ddd77de
#0.86targ=04f36a65e8a99ff8907b2e5e5ddd77de
#0.87targ=04f36a65e8a99dd8907b0e5e5ddd57de
#0.8799999=04f36a65e8a99ff8907b2e5e5ddd77de
#0.86targ=04d14845c8899dd890590c5c5ddd54dc
# Attack Parameters

NUM_GLITCH_ATTEMPTS = 500 # Number of times to try glitching
NUM_NORMAL_TRACES = 10 # Number of traces without glitch for comparison


# --- CONNECTION ---
scope = cw.scope()
target = cw.target(scope, cw.targets.CW305, bsfile=BITSTREAM_FILEPATH, force=True)


# Setup PLL1 on CW305 (assuming 10MHz external clock is provided by CW-Lite)
target.pll.pll_outfreq_set(50E6, 1) # Set PLL1 to 50 MHz (common FPGA clock)
target.pll.pll_enable_set(True)
target.pll.pll_outenable_set(True, 1)

# --- CONFIGURE CW-LITE SCOPE FOR POWER TRACING ---
# Use the clock generated by the CW305 (EXTCLK) as the ADC clock source
scope.default_setup()
scope.clock.adc_src = "extclk_x4" # Use 4x the target clock for sampling
scope.adc.samples = 3000 # Number of samples to capture per trace
scope.adc.offset = 40
scope.gain.gain = 25
scope.adc.presamples = 0
scope.adc.basic_mode = "falling_edge"
scope.trigger.triggers = 'tio4' # FPGA trigger pin TIO4 is used to arm the scope/glitch
scope.io.tio1 = "serial_tx"
scope.io.tio2 = "serial_rx"
scope.io.tio3 = "high_z" # Not used
scope.io.tio4 = "high_z" # Used for trigger, set by FPGA

# --- CONFIGURE CW-LITE GLITCH MODULE ---
scope.glitch.clk_src = "target" # Clock source for the glitch is the Target's EXTCLK
scope.glitch.trigger_src = "ext_single" # Wait for an external trigger (FPGA TIO4)
scope.glitch.output = "glitch_only" # Glitch pin pulls VCC-INT to ground (Crowbar)
scope.io.glitch_lp = False # Enable the low-power crowbar MOSFET
scope.io.glitch_hp = False

# Reset the glitch mechanism
scope.io.vglitch_reset()
# Out:
# (ChipWhisperer Target WARNING|File CW305.py:591) Using default Verilog defines (C:\Users\sbista\ChipWhisperer\chipwhisperer\software\chipwhisperer/hardware/firmware/cw305/cw305_aes_defines.v); if this is not what you want, provide them via the defines_files argument
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 30
# scope.gain.db                            changed from 5.5                       to 24.8359375
# scope.adc.basic_mode                     changed from low                       to rising_edge
# scope.adc.samples                        changed from 24400                     to 5000
# scope.adc.trig_count                     changed from 60946428                  to 87061170
# scope.clock.adc_src                      changed from clkgen_x1                 to clkgen_x4
# scope.clock.adc_freq                     changed from 96000000                  to 54063285
# scope.clock.adc_rate                     changed from 96000000.0                to 54063285.0
# scope.clock.freq_ctr                     changed from 0                         to 50006778
# scope.clock.clkgen_div                   changed from 1                         to 26
# scope.clock.clkgen_freq                  changed from 192000000.0               to 7384615.384615385
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen
# scope.io.tio_states                      changed from (1, 0, 0, 0)              to (0, 1, 0, 0)
# scope.io.cdc_settings                    changed from bytearray(b'\x01\x00\x00\x00') to bytearray(b'\x00\x00\x00\x00')

# %%
import time
for i in range(5):
    scope.clock.reset_adc()
    time.sleep(1)
    if scope.clock.adc_locked:
        break 
assert (scope.clock.adc_locked), "ADC failed to lock"

# %%
## --- 2. CAPTURE NORMAL TRACES ---
print("\n--- Collecting Normal Traces ---")
# Storage for the normal traces
normal_traces = []

# Function to run the AES encryption on the target
def run_aes(target, plaintext, key):
    target.set_key(key)
    target.simpleserial_write('p', plaintext)
    # The target.go() is handled by simpleserial_write for the CW305 target
    
    # Read the output from the target
    try:
        response = target.simpleserial_read('r', 16)
        if len(response) == 16:
            return response, True
        else:
            return None, False
    except Exception as e:
        print(f"Target read error: {e}")
        return None, False

for i in range(NUM_NORMAL_TRACES):
    scope.arm()
    output, success = run_aes(target, PLAINTEXT, KEY)
    
    if scope.capture():
        print(f"Timeout occurred on trace {i}")
        continue

    trace = scope.get_last_trace()
    normal_traces.append(trace)
    
    # Verify the output is the expected ciphertext
    if output == EXPECTED_CIPHERTEXT:
        print(f"Trace {i}: Success, Output: {output.hex()}")
    else:
        print(f"Trace {i}: FAIL, Output: {output.hex() if output else 'N/A'}")
        
print(f"Baseline trace collection complete. Collected {len(normal_traces)} good traces.")
# Out:
# --- Collecting Normal Traces ---
# Trace 0: Success, Output: 06f36a65e8a99ff8907b2e5e5ddd77de
# Trace 1: Success, Output: 06f36a65e8a99ff8907b2e5e5ddd77de
# Trace 2: Success, Output: 06f36a65e8a99ff8907b2e5e5ddd77de
# Trace 3: Success, Output: 06f36a65e8a99ff8907b2e5e5ddd77de
# Trace 4: Success, Output: 06f36a65e8a99ff8907b2e5e5ddd77de
# Trace 5: Success, Output: 06f36a65e8a99ff8907b2e5e5ddd77de
# Trace 6: Success, Output: 06f36a65e8a99ff8907b2e5e5ddd77de
# Trace 7: Success, Output: 06f36a65e8a99ff8907b2e5e5ddd77de
# Trace 8: Success, Output: 06f36a65e8a99ff8907b2e5e5ddd77de
# Trace 9: Success, Output: 06f36a65e8a99ff8907b2e5e5ddd77de
# Baseline trace collection complete. Collected 10 good traces.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ensure your normal_traces list has data
if not normal_traces:
    print("Error: No traces were collected. Run the 'Normal Trace Collection' loop first.")
else:
    # --- PLOT SETUP ---
    
    # 1. Get the first trace as a baseline
    first_trace = np.array(normal_traces[0])
    
    # 2. Get the average of all collected traces (provides a cleaner view)
    average_trace = np.average(normal_traces, axis=0)
    
    # --- PLOTTING ---
    plt.figure(figsize=(12, 6))
    
    # Plot the first collected trace
    plt.plot(first_trace, label="Single Trace (Trace 0)", color='red', alpha=0.5,linewidth=1)
    
    # Plot the average trace
    plt.plot(average_trace, label=f"Average of {len(normal_traces)} Traces", color='blue', linewidth=1)
    
    plt.title("Baseline Power Trace: AES on CW305 FPGA")
    plt.xlabel("Sample Number")
    plt.ylabel("Power Consumption (ADC Units)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
glitched_results = []
successful_faults = 0
successful_params = []
# --- VCC_INT SWEEP DEFINITION ---
# Start safe (1.0V) and go down to crash point (0.70V), in 10 steps
VCC_INT_TARGET = 0.9
VCC_SWEEP = np.linspace(0.9, 0.79, 10)  # VCC_SWEEP range from 1.0V to 0.70V

# --- OFFSET SWEEP DEFINITION ---
OFFSETS = np.linspace(-10.0, 10.0, 80)
FIXED_WIDTH = 4
ATTEMPTS_PER_POINT = 1

print("\n--- Starting Nested VCC/Offset Sweep ---")
print(f"Total Attempts: {len(VCC_SWEEP) * len(OFFSETS) * ATTEMPTS_PER_POINT}")


for vcc in VCC_SWEEP:
    # 1. SET THE NEW VULNERABLE VOLTAGE
    target.vccint_set(vcc)
    scope.glitch.width = FIXED_WIDTH
    
    # 2. SWEEP OFFSET AT THIS VOLTAGE LEVEL
    for offset in OFFSETS:
        scope.glitch.offset = offset
        
        # 3. ATTEMPT GLITCH MULTIPLE TIMES
        for attempt in range(ATTEMPTS_PER_POINT):
            
            i = len(glitched_results) # Tracking total attempts
            
            scope.arm()
            output, success = run_aes(target, PLAINTEXT, KEY)

            # --- CRASH & REPROGRAM LOGIC ---
            if scope.capture():
                # Handle timeout/crash
                try:
                    target.fpga_write(BITSTREAM_FILEPATH)
                except:
                    pass
                # Log the crash for plotting later
                glitched_results.append({'result': 'TIMEOUT', 'vcc': vcc, 'offset': offset})
                print(f"Attempt {i}: TIMEOUT (VCC={vcc:.2f}, o={offset:.1f}). Reprogrammed.")
                continue
            
            # --- FAULT DETECTION LOGIC ---
            output_hex = output.hex() if output else "N/A"
            expected_hex = EXPECTED_CIPHERTEXT.hex()
            
            if output_hex != expected_hex:
                result = 'FAULT'
                successful_faults += 1
            else:
                result = 'NORMAL'
                
            # Log the result
            glitched_results.append({'result': result, 'vcc': vcc, 'offset': offset, 'output': output_hex})
            
            # --- MODIFIED PRINT STATEMENT TO SHOW OUTPUT ---
            if result == 'FAULT':
                print(f"Attempt {i}: **FAULT** (VCC={vcc:.2f}, o={offset:.1f}) OUTPUT: {output_hex}")
                successful_params.append({'vcc': vcc, 'offset': offset, 'output': output_hex})
            else:
                # Prints the correct output for monitoring
                print(f"Attempt {i}: Normal (VCC={vcc:.2f}, o={offset:.1f}) OUTPUT: {output_hex}")
# Out:
# --- Starting Nested VCC/Offset Sweep ---
# Total Attempts: 800
# Attempt 0: Normal (VCC=0.90, o=-10.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 1: Normal (VCC=0.90, o=-9.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 2: Normal (VCC=0.90, o=-9.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 3: Normal (VCC=0.90, o=-9.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 4: Normal (VCC=0.90, o=-9.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 5: Normal (VCC=0.90, o=-8.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 6: Normal (VCC=0.90, o=-8.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 7: Normal (VCC=0.90, o=-8.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 8: Normal (VCC=0.90, o=-8.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 9: Normal (VCC=0.90, o=-7.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 10: Normal (VCC=0.90, o=-7.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 11: Normal (VCC=0.90, o=-7.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 12: Normal (VCC=0.90, o=-7.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 13: Normal (VCC=0.90, o=-6.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 14: Normal (VCC=0.90, o=-6.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 15: Normal (VCC=0.90, o=-6.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 16: Normal (VCC=0.90, o=-5.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 17: Normal (VCC=0.90, o=-5.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 18: Normal (VCC=0.90, o=-5.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 19: Normal (VCC=0.90, o=-5.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 20: Normal (VCC=0.90, o=-4.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 21: Normal (VCC=0.90, o=-4.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 22: Normal (VCC=0.90, o=-4.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 23: Normal (VCC=0.90, o=-4.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 24: Normal (VCC=0.90, o=-3.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 25: Normal (VCC=0.90, o=-3.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 26: Normal (VCC=0.90, o=-3.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 27: Normal (VCC=0.90, o=-3.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 28: Normal (VCC=0.90, o=-2.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 29: Normal (VCC=0.90, o=-2.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# Attempt 30: Normal (VCC=0.90, o=-2.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 31: Normal (VCC=0.90, o=-2.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 32: Normal (VCC=0.90, o=-1.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 33: Normal (VCC=0.90, o=-1.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 34: Normal (VCC=0.90, o=-1.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 35: Normal (VCC=0.90, o=-1.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 36: Normal (VCC=0.90, o=-0.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 37: Normal (VCC=0.90, o=-0.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 38: Normal (VCC=0.90, o=-0.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# Attempt 39: Normal (VCC=0.90, o=-0.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 40: Normal (VCC=0.90, o=0.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 41: Normal (VCC=0.90, o=0.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 42: Normal (VCC=0.90, o=0.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 43: Normal (VCC=0.90, o=0.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 44: Normal (VCC=0.90, o=1.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 45: Normal (VCC=0.90, o=1.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 46: Normal (VCC=0.90, o=1.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 47: Normal (VCC=0.90, o=1.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 48: Normal (VCC=0.90, o=2.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 49: Normal (VCC=0.90, o=2.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 50: Normal (VCC=0.90, o=2.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt
OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# Attempt 118: Normal (VCC=0.89, o=-0.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 119: Normal (VCC=0.89, o=-0.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 120: Normal (VCC=0.89, o=0.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 121: Normal (VCC=0.89, o=0.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 122: Normal (VCC=0.89, o=0.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 123: Normal (VCC=0.89, o=0.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 124: Normal (VCC=0.89, o=1.1) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 125: Normal (VCC=0.89, o=1.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 126: Normal (VCC=0.89, o=1.6) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 127: Normal (VCC=0.89, o=1.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 128: Normal (VCC=0.89, o=2.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 129: Normal (VCC=0.89, o=2.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 130: Normal (VCC=0.89, o=2.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 131: Normal (VCC=0.89, o=2.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 132: Normal (VCC=0.89, o=3.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 133: Normal (VCC=0.89, o=3.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 134: Normal (VCC=0.89, o=3.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 135: Normal (VCC=0.89, o=3.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 136: Normal (VCC=0.89, o=4.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 137: Normal (VCC=0.89, o=4.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 138: Normal (VCC=0.89, o=4.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 139: Normal (VCC=0.89, o=4.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 140: Normal (VCC=0.89, o=5.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 141: Normal (VCC=0.89, o=5.4) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 142: Normal (VCC=0.89, o=5.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 143: Normal (VCC=0.89, o=5.9) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 144: Normal (VCC=0.89, o=6.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 145: Normal (VCC=0.89, o=6.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 146: Normal (VCC=0.89, o=6.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 147: Normal (VCC=0.89, o=7.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 148: Normal (VCC=0.89, o=7.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 149: Normal (VCC=0.89, o=7.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 150: Normal (VCC=0.89, o=7.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 151: Normal (VCC=0.89, o=8.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 152: Normal (VCC=0.89, o=8.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 153: Normal (VCC=0.89, o=8.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 154: Normal (VCC=0.89, o=8.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 155: Normal (VCC=0.89, o=9.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 156: Normal (VCC=0.89, o=9.2) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 157: Normal (VCC=0.89, o=9.5) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 158: Normal (VCC=0.89, o=9.7) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 159: Normal (VCC=0.89, o=10.0) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 160: **FAULT** (VCC=0.88, o=-10.0) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 161: **FAULT** (VCC=0.88, o=-9.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 162: **FAULT** (VCC=0.88, o=-9.5) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 163: **FAULT** (VCC=0.88, o=-9.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 164: **FAULT** (VCC=0.88, o=-9.0) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 165: **FAULT** (VCC=0.88, o=-8.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 166: **FAULT** (VCC=0.88, o=-8.5) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 167: **FAULT** (VCC=0.88, o=-8.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 168: **FAULT** (VCC=0.88, o=-8.0) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 169: **FAULT** (VCC=0.88, o=-7.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 170: **FAULT** (VCC=0.88, o=-7.5) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 171: **FAULT** (VCC=0.88, o=-7.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 172: **FAULT** (VCC=0.88, o=-7.0) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 173: **FAULT** (VCC=0.88, o=-6.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 174: **FAULT** (VCC=0.88, o=-6.5) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 175: **FAULT** (VCC=0.88, o=-6.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 176: **FAULT** (VCC=0.88, o=-5.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 177: **FAULT** (VCC=0.88, o=-5.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 178: **FAULT** (VCC=0.88, o=-5.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 179: **FAULT** (VCC=0.88, o=-5.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 180: **FAULT** (VCC=0.88, o=-4.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 181: **FAULT** (VCC=0.88, o=-4.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 182: **FAULT** (VCC=0.88, o=-4.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 183: **FAULT** (VCC=0.88, o=-4.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 184: **FAULT** (VCC=0.88, o=-3.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 185: **FAULT** (VCC=0.88, o=-3.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 186: **FAULT** (VCC=0.88, o=-3.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 187: **FAULT** (VCC=0.88, o=-3.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 188: **FAULT** (VCC=0.88, o=-2.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# Attempt 189: **FAULT** (VCC=0.88, o=-2.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 190: **FAULT** (VCC=0.88, o=-2.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 191: **FAULT** (VCC=0.88, o=-2.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 192: **FAULT** (VCC=0.88, o=-1.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 193: **FAULT** (VCC=0.88, o=-1.6) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 194: **FAULT** (VCC=0.88, o=-1.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 195: **FAULT** (VCC=0.88, o=-1.1) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 196: **FAULT** (VCC=0.88, o=-0.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 197: **FAULT** (VCC=0.88, o=-0.6) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 198: **FAULT** (VCC=0.88, o=-0.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# Attempt 199: **FAULT** (VCC=0.88, o=-0.1) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 200: **FAULT** (VCC=0.88, o=0.1) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 201: **FAULT** (VCC=0.88, o=0.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 202: **FAULT** (VCC=0.88, o=0.6) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 203: **FAULT** (VCC=0.88, o=0.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 204: **FAULT** (VCC=0.88, o=1.1) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 205: **FAULT** (VCC=0.88, o=1.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 206: **FAULT** (VCC=0.88, o=1.6) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 207: **FAULT** (VCC=0.88, o=1.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 208: **FAULT** (VCC=0.88, o=2.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 209: **FAULT** (VCC=0.88, o=2.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 210: **FAULT** (VCC=0.88, o=2.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 211: **FAULT** (VCC=0.88, o=2.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 212: **FAULT** (VCC=0.88, o=3.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 213: **FAULT** (VCC=0.88, o=3.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 214: **FAULT** (VCC=0.88, o=3.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 215: **FAULT** (VCC=0.88, o=3.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 216: **FAULT** (VCC=0.88, o=4.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 217: **FAULT** (VCC=0.88, o=4.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 218: **FAULT** (VCC=0.88, o=4.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 219: **FAULT** (VCC=0.88, o=4.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 220: **FAULT** (VCC=0.88, o=5.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 221: **FAULT** (VCC=0.88, o=5.4) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 222: **FAULT** (VCC=0.88, o=5.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 223: **FAULT** (VCC=0.88, o=5.9) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 224: **FAULT** (VCC=0.88, o=6.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 225: **FAULT** (VCC=0.88, o=6.5) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 226: **FAULT** (VCC=0.88, o=6.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 227: **FAULT** (VCC=0.88, o=7.0) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 228: **FAULT** (VCC=0.88, o=7.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 229: **FAULT** (VCC=0.88, o=7.5) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 230: **FAULT** (VCC=0.88, o=7.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 231: **FAULT** (VCC=0.88, o=8.0) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 232: **FAULT** (VCC=0.88, o=8.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 233: **FAULT** (VCC=0.88, o=8.5) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 234: **FAULT** (VCC=0.88, o=8.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 235: **FAULT** (VCC=0.88, o=9.0) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 236: **FAULT** (VCC=0.88, o=9.2) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 237: **FAULT** (VCC=0.88, o=9.5) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 238: **FAULT** (VCC=0.88, o=9.7) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 239: **FAULT** (VCC=0.88, o=10.0) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 240: **FAULT** (VCC=0.86, o=-10.0) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 241: **FAULT** (VCC=0.86, o=-9.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 242: **FAULT** (VCC=0.86, o=-9.5) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 243: **FAULT** (VCC=0.86, o=-9.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 244: **FAULT** (VCC=0.86, o=-9.0) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 245: **FAULT** (VCC=0.86, o=-8.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 246: **FAULT** (VCC=0.86, o=-8.5) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 247: **FAULT** (VCC=0.86, o=-8.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 248: **FAULT** (VCC=0.86, o=-8.0) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 249: **FAULT** (VCC=0.86, o=-7.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 250: **FAULT** (VCC=0.86, o=-7.5) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 251: **FAULT** (VCC=0.86, o=-7.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 252: **FAULT** (VCC=0.86, o=-7.0) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 253: **FAULT** (VCC=0.86, o=-6.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 254: **FAULT** (VCC=0.86, o=-6.5) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 255: **FAULT** (VCC=0.86, o=-6.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 256: **FAULT** (VCC=0.86, o=-5.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 257: **FAULT** (VCC=0.86, o=-5.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 258: **FAULT** (VCC=0.86, o=-5.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 259: **FAULT** (VCC=0.86, o=-5.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 260: **FAULT** (VCC=0.86, o=-4.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 261: **FAULT** (VCC=0.86, o=-4.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 262: **FAULT** (VCC=0.86, o=-4.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 263: **FAULT** (VCC=0.86, o=-4.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 264: **FAULT** (VCC=0.86, o=-3.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 265: **FAULT** (VCC=0.86, o=-3.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 266: **FAULT** (VCC=0.86, o=-3.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 267: **FAULT** (VCC=0.86, o=-3.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 268: **FAULT** (VCC=0.86, o=-2.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 269: **FAULT** (VCC=0.86, o=-2.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 270: **FAULT** (VCC=0.86, o=-2.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 271: **FAULT** (VCC=0.86, o=-2.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 272: **FAULT** (VCC=0.86, o=-1.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# Attempt 273: **FAULT** (VCC=0.86, o=-1.6) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 274: **FAULT** (VCC=0.86, o=-1.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 275: **FAULT** (VCC=0.86, o=-1.1) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 276: **FAULT** (VCC=0.86, o=-0.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 277: **FAULT** (VCC=0.86, o=-0.6) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 278: **FAULT** (VCC=0.86, o=-0.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 279: **FAULT** (VCC=0.86, o=-0.1) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 280: **FAULT** (VCC=0.86, o=0.1) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 281: **FAULT** (VCC=0.86, o=0.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 282: **FAULT** (VCC=0.86, o=0.6) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 283: **FAULT** (VCC=0.86, o=0.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 284: **FAULT** (VCC=0.86, o=1.1) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 285: **FAULT** (VCC=0.86, o=1.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 286: **FAULT** (VCC=0.86, o=1.6) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 287: **FAULT** (VCC=0.86, o=1.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 288: **FAULT** (VCC=0.86, o=2.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 289: **FAULT** (VCC=0.86, o=2.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 290: **FAULT** (VCC=0.86, o=2.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 291: **FAULT** (VCC=0.86, o=2.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 292: **FAULT** (VCC=0.86, o=3.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 293: **FAULT** (VCC=0.86, o=3.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 294: **FAULT** (VCC=0.86, o=3.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 295: **FAULT** (VCC=0.86, o=3.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 296: **FAULT** (VCC=0.86, o=4.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 297: **FAULT** (VCC=0.86, o=4.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 298: **FAULT** (VCC=0.86, o=4.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 299: **FAULT** (VCC=0.86, o=4.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 300: **FAULT** (VCC=0.86, o=5.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 301: **FAULT** (VCC=0.86, o=5.4) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 302: **FAULT** (VCC=0.86, o=5.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 303: **FAULT** (VCC=0.86, o=5.9) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 304: **FAULT** (VCC=0.86, o=6.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 305: **FAULT** (VCC=0.86, o=6.5) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 306: **FAULT** (VCC=0.86, o=6.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 307: **FAULT** (VCC=0.86, o=7.0) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 308: **FAULT** (VCC=0.86, o=7.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 309: **FAULT** (VCC=0.86, o=7.5) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 310: **FAULT** (VCC=0.86, o=7.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 311: **FAULT** (VCC=0.86, o=8.0) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 312: **FAULT** (VCC=0.86, o=8.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 313: **FAULT** (VCC=0.86, o=8.5) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 314: **FAULT** (VCC=0.86, o=8.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 315: **FAULT** (VCC=0.86, o=9.0) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 316: **FAULT** (VCC=0.86, o=9.2) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 317: **FAULT** (VCC=0.86, o=9.5) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 318: **FAULT** (VCC=0.86, o=9.7) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 319: **FAULT** (VCC=0.86, o=10.0) OUTPUT: 04d14845c8899dd890590c5c5ddd55dc
# Attempt 320: **FAULT** (VCC=0.85, o=-10.0) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 321: **FAULT** (VCC=0.85, o=-9.7) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 322: **FAULT** (VCC=0.85, o=-9.5) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 323: **FAULT** (VCC=0.85, o=-9.2) OUTPUT: 04d04845c8889cd890580c5c5cdc54dc
# Attempt 324: **FAULT** (VCC=0.85, o=-9.0) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 325: **FAULT** (VCC=0.85, o=-8.7) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 326: **FAULT** (VCC=0.85, o=-8.5) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 327: **FAULT** (VCC=0.85, o=-8.2) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 328: **FAULT** (VCC=0.85, o=-8.0) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 329: **FAULT** (VCC=0.85, o=-7.7) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 330: **FAULT** (VCC=0.85, o=-7.5) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 331: **FAULT** (VCC=0.85, o=-7.2) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 332: **FAULT** (VCC=0.85, o=-7.0) OUTPUT: 04d04845c8889cd890580c5c5cdc54dc
# Attempt 333: **FAULT** (VCC=0.85, o=-6.7) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 334: **FAULT** (VCC=0.85, o=-6.5) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 335: **FAULT** (VCC=0.85, o=-6.2) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 336: **FAULT** (VCC=0.85, o=-5.9) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 337: **FAULT** (VCC=0.85, o=-5.7) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 338: **FAULT** (VCC=0.85, o=-5.4) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 339: **FAULT** (VCC=0.85, o=-5.2) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 340: **FAULT** (VCC=0.85, o=-4.9) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 341: **FAULT** (VCC=0.85, o=-4.7) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 342: **FAULT** (VCC=0.85, o=-4.4) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 343: **FAULT** (VCC=0.85, o=-4.2) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 344: **FAULT** (VCC=0.85, o=-3.9) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 345: **FAULT** (VCC=0.85, o=-3.7) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 346: **FAULT** (VCC=0.85, o=-3.4) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 347: **FAULT** (VCC=0.85, o=-3.2) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 348: **FAULT** (VCC=0.85, o=-2.9) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 349: **FAULT** (VCC=0.85, o=-2.7) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 350: **FAULT** (VCC=0.85, o=-2.4) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 351: **FAULT** (VCC=0.85, o=-2.2) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 352: **FAULT** (VCC=0.85, o=-1.9) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 353: **FAULT** (VCC=0.85, o=-1.6) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# Attempt 354: **FAULT** (VCC=0.85, o=-1.4) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 355: **FAULT** (VCC=0.85, o=-1.1) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 356: **FAULT** (VCC=0.85, o=-0.9) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 357: **FAULT** (VCC=0.85, o=-0.6) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 358: **FAULT** (VCC=0.85, o=-0.4) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 359: **FAULT** (VCC=0.85, o=-0.1) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 360: **FAULT** (VCC=0.85, o=0.1) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 361: **FAULT** (VCC=0.85, o=0.4) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 362: **FAULT** (VCC=0.85, o=0.6) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 363: **FAULT** (VCC=0.85, o=0.9) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 364: **FAULT** (VCC=0.85, o=1.1) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 365: **FAULT** (VCC=0.85, o=1.4) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 366: **FAULT** (VCC=0.85, o=1.6) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 367: **FAULT** (VCC=0.85, o=1.9) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 368: **FAULT** (VCC=0.85, o=2.2) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 369: **FAULT** (VCC=0.85, o=2.4) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 370: **FAULT** (VCC=0.85, o=2.7) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 371: **FAULT** (VCC=0.85, o=2.9) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 372: **FAULT** (VCC=0.85, o=3.2) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 373: **FAULT** (VCC=0.85, o=3.4) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 374: **FAULT** (VCC=0.85, o=3.7) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 375: **FAULT** (VCC=0.85, o=3.9) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 376: **FAULT** (VCC=0.85, o=4.2) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 377: **FAULT** (VCC=0.85, o=4.4) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 378: **FAULT** (VCC=0.85, o=4.7) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 379: **FAULT** (VCC=0.85, o=4.9) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 380: **FAULT** (VCC=0.85, o=5.2) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 381: **FAULT** (VCC=0.85, o=5.4) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 382: **FAULT** (VCC=0.85, o=5.7) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 383: **FAULT** (VCC=0.85, o=5.9) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 384: **FAULT** (VCC=0.85, o=6.2) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 385: **FAULT** (VCC=0.85, o=6.5) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 386: **FAULT** (VCC=0.85, o=6.7) OUTPUT: 04d04845c8889cd890580c5c5cdc54dc
# Attempt 387: **FAULT** (VCC=0.85, o=7.0) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 388: **FAULT** (VCC=0.85, o=7.2) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 389: **FAULT** (VCC=0.85, o=7.5) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 390: **FAULT** (VCC=0.85, o=7.7) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 391: **FAULT** (VCC=0.85, o=8.0) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 392: **FAULT** (VCC=0.85, o=8.2) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 393: **FAULT** (VCC=0.85, o=8.5) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 394: **FAULT** (VCC=0.85, o=8.7) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 395: **FAULT** (VCC=0.85, o=9.0) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 396: **FAULT** (VCC=0.85, o=9.2) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 397: **FAULT** (VCC=0.85, o=9.5) OUTPUT: 04d04844c8889cd890580c5c5cdc545c
# Attempt 398: **FAULT** (VCC=0.85, o=9.7) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 399: **FAULT** (VCC=0.85, o=10.0) OUTPUT: 04d04844c8889cd890580c5c5cdc54dc
# Attempt 400: **FAULT** (VCC=0.84, o=-10.0) OUTPUT: 00100004000018181010001c10101000
# Attempt 401: **FAULT** (VCC=0.84, o=-9.7) OUTPUT: 00100004000010181010001c10101000
# Attempt 402: **FAULT** (VCC=0.84, o=-9.5) OUTPUT: 00100004000010181010001c10101000
# Attempt 403: **FAULT** (VCC=0.84, o=-9.2) OUTPUT: 00100004000010181010001c10101000
# Attempt 404: **FAULT** (VCC=0.84, o=-9.0) OUTPUT: 00100004000010181010001c10101000
# Attempt 405: **FAULT** (VCC=0.84, o=-8.7) OUTPUT: 00100004000010181010001c10101000
# Attempt 406: **FAULT** (VCC=0.84, o=-8.5) OUTPUT: 00100004000010181010001c10101000
# Attempt 407: **FAULT** (VCC=0.84, o=-8.2) OUTPUT: 00100004000010181010001c10101000
# Attempt 408: **FAULT** (VCC=0.84, o=-8.0) OUTPUT: 00100004000018581010001c10101000
# Attempt 409: **FAULT** (VCC=0.84, o=-7.7) OUTPUT: 00100004000018581010001c10141000
# Attempt 410: **FAULT** (VCC=0.84, o=-7.5) OUTPUT: 00100004000018181010001c10141000
# Attempt 439: **FAULT** (VCC=0.84, o=-0.1) OUTPUT: 00100004000010181010001c10101000
# Attempt 440: **FAULT** (VCC=0.84, o=0.1) OUTPUT: 00100004000010181010001c10101000
# Attempt 441: **FAULT** (VCC=0.84, o=0.4) OUTPUT: 00100004000010181010001c10101000
# Attempt 442: **FAULT** (VCC=0.84, o=0.6) OUTPUT: 00100004000018581010001c10141000
# Attempt 443: **FAULT** (VCC=0.84, o=0.9) OUTPUT: 00100004000010181010001c10101000
# Attempt 444: **FAULT** (VCC=0.84, o=1.1) OUTPUT: 00000004000018181010001c10101000
# Attempt 445: **FAULT** (VCC=0.84, o=1.4) OUTPUT: 00100004000010181010001c10101000
# Attempt 446: **FAULT** (VCC=0.84, o=1.6) OUTPUT: 00100004000018181010001c10101000
# Attempt 447: **FAULT** (VCC=0.84, o=1.9) OUTPUT: 00100004000018181010001c10101000
# Attempt 448: **FAULT** (VCC=0.84, o=2.2) OUTPUT: 00100004000010181010001c10101000
# Attempt 449: **FAULT** (VCC=0.84, o=2.4) OUTPUT: 00100004000018181010001c10101000
# Attempt 450: **FAULT** (VCC=0.84, o=2.7) OUTPUT: 00100004000010181010001c10101000
# Attempt 451: **FAULT** (VCC=0.84, o=2.9) OUTPUT: 00100004000010181010001c10101000
# Attempt 452: **FAULT** (VCC=0.84, o=3.2) OUTPUT: 00100004000018181010001c10101000
# Attempt 453: **FAULT** (VCC=0.84, o=3.4) OUTPUT: 00100004000018181010001c10101000
# Attempt 454: **FAULT** (VCC=0.84, o=3.7) OUTPUT: 00100004000018181010001c10101000
# Attempt 455: **FAULT** (VCC=0.84, o=3.9) OUTPUT: 00100004000010181010001c10101000
# Attempt 456: **FAULT** (VCC=0.84, o=4.2) OUTPUT: 00100004000010181010001c10101000
# Attempt 457: **FAULT** (VCC=0.84, o=4.4) OUTPUT: 00100004000018181010001c10101000
# Attempt 458: **FAULT** (VCC=0.84, o=4.7) OUTPUT: 00100004000010581010001c10101000
# Attempt 459: **FAULT** (VCC=0.84, o=4.9) OUTPUT: 00100004000010181010001c10101000
# Attempt 460: **FAULT** (VCC=0.84, o=5.2) OUTPUT: 00100004000010181010001c10101000
# Attempt 461: **FAULT** (VCC=0.84, o=5.4) OUTPUT: 00100004000010181010001c10101000
# Attempt 462: **FAULT** (VCC=0.84, o=5.7) OUTPUT: 00100004000018181010001c10141000
# Attempt 463: **FAULT** (VCC=0.84, o=5.9) OUTPUT: 00100004000010181010001c10101000
# Attempt 464: **FAULT** (VCC=0.84, o=6.2) OUTPUT: 00100004000018181010001c10101000
# Attempt 465: **FAULT** (VCC=0.84, o=6.5) OUTPUT: 00100004000018581010001c10101000
# Attempt 466: **FAULT** (VCC=0.84, o=6.7) OUTPUT: 00100004000018181010001c10101000
# Attempt 467: **FAULT** (VCC=0.84, o=7.0) OUTPUT: 00100004000010181010001c10101000
# Attempt 468: **FAULT** (VCC=0.84, o=7.2) OUTPUT: 00100004000018181010001c10101000
# Attempt 469: **FAULT** (VCC=0.84, o=7.5) OUTPUT: 00100004000010181010001c10101000
# Attempt 470: **FAULT** (VCC=0.84, o=7.7) OUTPUT: 00100004000018181010001c10101000
# Attempt 471: **FAULT** (VCC=0.84, o=8.0) OUTPUT: 00100004000010181010001c10101000
# Attempt 472: **FAULT** (VCC=0.84, o=8.2) OUTPUT: 00100004000010181010001c10101000
# Attempt 473: **FAULT** (VCC=0.84, o=8.5) OUTPUT: 00100004000018181010001c10101000
# Attempt 474: **FAULT** (VCC=0.84, o=8.7) OUTPUT: 00100004000010181010001c10101000
# Attempt 475: **FAULT** (VCC=0.84, o=9.0) OUTPUT: 00100004000010181010001c10101000
# Attempt 476: **FAULT** (VCC=0.84, o=9.2) OUTPUT: 00100004000010181010001c10101000
# Attempt 477: **FAULT** (VCC=0.84, o=9.5) OUTPUT: 00100004000018181010001c10101000
# Attempt 478: **FAULT** (VCC=0.84, o=9.7) OUTPUT: 00100004000010181010001c10101000
# Attempt 479: **FAULT** (VCC=0.84, o=10.0) OUTPUT: 00100004000010181010001c10101000
# Attempt 480: **FAULT** (VCC=0.83, o=-10.0) OUTPUT: 00000000000000100000001000000000
# Attempt 481: **FAULT** (VCC=0.83, o=-9.7) OUTPUT: 00000000000000100000001000000000
# Attempt 482: **FAULT** (VCC=0.83, o=-9.5) OUTPUT: 00000000000010100000001000000000
# Attempt 483: **FAULT** (VCC=0.83, o=-9.2) OUTPUT: 00000000000010100000001000000000
# Attempt 484: **FAULT** (VCC=0.83, o=-9.0) OUTPUT: 00000000000000100000001000000000
# Attempt 485: **FAULT** (VCC=0.83, o=-8.7) OUTPUT: 00000000000010100000001000000000
# Attempt 486: **FAULT** (VCC=0.83, o=-8.5) OUTPUT: 00000000000000100000001000000000
# Attempt 487: **FAULT** (VCC=0.83, o=-8.2) OUTPUT: 00000000000000100000001000000000
# Attempt 488: **FAULT** (VCC=0.83, o=-8.0) OUTPUT: 00000000000000100000001000000000
# Attempt 489: **FAULT** (VCC=0.83, o=-7.7) OUTPUT: 00000000000000100000001000000000
# Attempt 490: **FAULT** (VCC=0.83, o=-7.5) OUTPUT: 00000000000000100000001000000000
# Attempt 491: **FAULT** (VCC=0.83, o=-7.2) OUTPUT: 00000000000000100000001000000000
# Attempt 492: **FAULT** (VCC=0.83, o=-7.0) OUTPUT: 00000000000000100000001000000000
# Attempt 493: **FAULT** (VCC=0.83, o=-6.7) OUTPUT: 00000000000000100000001000000000
# Attempt 494: **FAULT** (VCC=0.83, o=-6.5) OUTPUT: 00000000000000100000001000000000
# Attempt 495: **FAULT** (VCC=0.83, o=-6.2) OUTPUT: 00000000000010100000001000000000
# Attempt 496: **FAULT** (VCC=0.83, o=-5.9) OUTPUT: 00000000000000100000001000000000
# Attempt 497: **FAULT** (VCC=0.83, o=-5.7) OUTPUT: 00000000000010100000001000000000
# Attempt 498: **FAULT** (VCC=0.83, o=-5.4) OUTPUT: 00000000000010100000001000000000
# Attempt 499: **FAULT** (VCC=0.83, o=-5.2) OUTPUT: 00000000000010100000001000000000
# Attempt 500: **FAULT** (VCC=0.83, o=-4.9) OUTPUT: 00000000000000100000001000000000
# Attempt 501: **FAULT** (VCC=0.83, o=-4.7) OUTPUT: 00000000000000100000001000000000
# Attempt 502: **FAULT** (VCC=0.83, o=-4.4) OUTPUT: 00000000000000100000001000000000
# Attempt 503: **FAULT** (VCC=0.83, o=-4.2) OUTPUT: 00000000000000100000001000000000
# Attempt 504: **FAULT** (VCC=0.83, o=-3.9) OUTPUT: 00000000000010100000001000000000
# Attempt 505: **FAULT** (VCC=0.83, o=-3.7) OUTPUT: 00000000000010100000001000000000
# Attempt 506: **FAULT** (VCC=0.83, o=-3.4) OUTPUT: 00000000000010100000001000000000
# Attempt 507: **FAULT** (VCC=0.83, o=-3.2) OUTPUT: 00000000000000100000001000000000
# Attempt 508: **FAULT** (VCC=0.83, o=-2.9) OUTPUT: 00000000000000100000001000000000
# Attempt 509: **FAULT** (VCC=0.83, o=-2.7) OUTPUT: 00000000000000100000001000000000
# Attempt 510: **FAULT** (VCC=0.83, o=-2.4) OUTPUT: 00000000000000100000001000000000
# Attempt 511: **FAULT** (VCC=0.83, o=-2.2) OUTPUT: 00000000000010100000001000000000
# Attempt 512: **FAULT** (VCC=0.83, o=-1.9) OUTPUT: 00000000000010100000001000000000
# Attempt 513: **FAULT** (VCC=0.83, o=-1.6) OUTPUT: 00000000000000100000001000000000
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# Attempt 514: **FAULT** (VCC=0.83, o=-1.4) OUTPUT: 00000000000000100000001000000000
# Attempt 515: **FAULT** (VCC=0.83, o=-1.1) OUTPUT: 00000000000000100000001000000000
# Attempt 516: **FAULT** (VCC=0.83, o=-0.9) OUTPUT: 00000000000010100000001000000000
# Attempt 517: **FAULT** (VCC=0.83, o=-0.6) OUTPUT: 00000000000000100000001000000000
# Attempt 518: **FAULT** (VCC=0.83, o=-0.4) OUTPUT: 00000000000000100000001000000000
# Attempt 519: **FAULT** (VCC=0.83, o=-0.1) OUTPUT: 00000000000000100000001000000000
# Attempt 520: **FAULT** (VCC=0.83, o=0.1) OUTPUT: 00000000000000100000001000000000
# Attempt 521: **FAULT** (VCC=0.83, o=0.4) OUTPUT: 00000000000000100000001000000000
# Attempt 522: **FAULT** (VCC=0.83, o=0.6) OUTPUT: 00000000000000100000001000000000
# Attempt 523: **FAULT** (VCC=0.83, o=0.9) OUTPUT: 00000000000000100000001000000000
# Attempt 524: **FAULT** (VCC=0.83, o=1.1) OUTPUT: 00000000000010100000001000000000
# Attempt 525: **FAULT** (VCC=0.83, o=1.4) OUTPUT: 00000000000010100000001000000000
# Attempt 526: **FAULT** (VCC=0.83, o=1.6) OUTPUT: 00000000000010100000001000000000
# Attempt 527: **FAULT** (VCC=0.83, o=1.9) OUTPUT: 00000000000010100000001000000000
# Attempt 528: **FAULT** (VCC=0.83, o=2.2) OUTPUT: 00000000000000100000001000000000
# Attempt 529: **FAULT** (VCC=0.83, o=2.4) OUTPUT: 00000000000000100000001000000000
# Attempt 530: **FAULT** (VCC=0.83, o=2.7) OUTPUT: 00000000000000100000001000000000
# Attempt 531: **FAULT** (VCC=0.83, o=2.9) OUTPUT: 00000000000000100000001000000000
# Attempt 532: **FAULT** (VCC=0.83, o=3.2) OUTPUT: 00000000000000100000001000000000
# Attempt 533: **FAULT** (VCC=0.83, o=3.4) OUTPUT: 00000000000010100000001000000000
# Attempt 534: **FAULT** (VCC=0.83, o=3.7) OUTPUT: 00000000000000100000001000000000
# Attempt 535: **FAULT** (VCC=0.83, o=3.9) OUTPUT: 00000000000000100000001000000000
# Attempt 536: **FAULT** (VCC=0.83, o=4.2) OUTPUT: 00000000000000100000001000000000
# Attempt 537: **FAULT** (VCC=0.83, o=4.4) OUTPUT: 00000000000000100000001000000000
# Attempt 538: **FAULT** (VCC=0.83, o=4.7) OUTPUT: 00000000000000100000001000000000
# Attempt 539: **FAULT** (VCC=0.83, o=4.9) OUTPUT: 00000000000010100000001000000000
# Attempt 540: **FAULT** (VCC=0.83, o=5.2) OUTPUT: 00000000000000100000001000000000
# Attempt 541: **FAULT** (VCC=0.83, o=5.4) OUTPUT: 00000000000010100000001000000000
# Attempt 542: **FAULT** (VCC=0.83, o=5.7) OUTPUT: 00000000000000100000001000000000
# Attempt 543: **FAULT** (VCC=0.83, o=5.9) OUTPUT: 00000000000000100000001000000000
# Attempt 544: **FAULT** (VCC=0.83, o=6.2) OUTPUT: 00000000000000100000001000000000
# Attempt 545: **FAULT** (VCC=0.83, o=6.5) OUTPUT: 00000000000000100000001000000000
# Attempt 546: **FAULT** (VCC=0.83, o=6.7) OUTPUT: 00000000000000100000001000000000
# Attempt 547: **FAULT** (VCC=0.83, o=7.0) OUTPUT: 00000000000010100000001000000000
# Attempt 548: **FAULT** (VCC=0.83, o=7.2) OUTPUT: 00000000000010100000001000000000
# Attempt 549: **FAULT** (VCC=0.83, o=7.5) OUTPUT: 00000000000000100000001000000000
# Attempt 550: **FAULT** (VCC=0.83, o=7.7) OUTPUT: 00000000000010100000001000000000
# Attempt 551: **FAULT** (VCC=0.83, o=8.0) OUTPUT: 00000000000000100000001000000000
# Attempt 552: **FAULT** (VCC=0.83, o=8.2) OUTPUT: 00000000000010100000001000000000
# Attempt 553: **FAULT** (VCC=0.83, o=8.5) OUTPUT: 00000000000010100000001000000000
# Attempt 554: **FAULT** (VCC=0.83, o=8.7) OUTPUT: 00000000000010100000001000000000
# Attempt 555: **FAULT** (VCC=0.83, o=9.0) OUTPUT: 00000000000000100000001000000000
# Attempt 556: **FAULT** (VCC=0.83, o=9.2) OUTPUT: 00000000000000100000001000000000
# Attempt 557: **FAULT** (VCC=0.83, o=9.5) OUTPUT: 00000000000000100000001000000000
# Attempt 558: **FAULT** (VCC=0.83, o=9.7) OUTPUT: 00000000000000100000001000000000
# Attempt 559: **FAULT** (VCC=0.83, o=10.0) OUTPUT: 00000000000000100000001000000000
# Attempt 560: **FAULT** (VCC=0.81, o=-10.0) OUTPUT: 00000000000000000000000000000000
# Attempt 561: **FAULT** (VCC=0.81, o=-9.7) OUTPUT: 00000000000000000000000000000000
# Attempt 562: **FAULT** (VCC=0.81, o=-9.5) OUTPUT: 00000000000000000000000000000000
# Attempt 563: **FAULT** (VCC=0.81, o=-9.2) OUTPUT: 00000000000000000000000000000000
# Attempt 564: **FAULT** (VCC=0.81, o=-9.0) OUTPUT: 00000000000000000000000000000000
# Attempt 565: **FAULT** (VCC=0.81, o=-8.7) OUTPUT: 00000000000000000000000000000000
# Attempt 566: **FAULT** (VCC=0.81, o=-8.5) OUTPUT: 00000000000000000000000000000000
# Attempt 567: **FAULT** (VCC=0.81, o=-8.2) OUTPUT: 00000000000000000000000000000000
# ...
# Attempt 612: **FAULT** (VCC=0.81, o=3.2) OUTPUT: 00000000000000000000000000000000
# Attempt 613: **FAULT** (VCC=0.81, o=3.4) OUTPUT: 00000000000000000000000000000000
# Attempt 614: **FAULT** (VCC=0.81, o=3.7) OUTPUT: 00000000000000000000000000000000
# Attempt 615: **FAULT** (VCC=0.81, o=3.9) OUTPUT: 00000000000000000000000000000000
# Attempt 616: **FAULT** (VCC=0.81, o=4.2) OUTPUT: 00000000000000000000000000000000
# Attempt 617: **FAULT** (VCC=0.81, o=4.4) OUTPUT: 00000000000000000000000000000000
# Attempt 618: **FAULT** (VCC=0.81, o=4.7) OUTPUT: 00000000000000000000000000000000
# Attempt 619: **FAULT** (VCC=0.81, o=4.9) OUTPUT: 00000000000000000000000000000000
# Attempt 620: **FAULT** (VCC=0.81, o=5.2) OUTPUT: 00000000000000000000000000000000
# Attempt 621: **FAULT** (VCC=0.81, o=5.4) OUTPUT: 00000000000000000000000000000000
# Attempt 622: **FAULT** (VCC=0.81, o=5.7) OUTPUT: 00000000000000000000000000000000
# Attempt 623: **FAULT** (VCC=0.81, o=5.9) OUTPUT: 00000000000000000000000000000000
# Attempt 624: **FAULT** (VCC=0.81, o=6.2) OUTPUT: 00000000000000000000000000000000
# Attempt 625: **FAULT** (VCC=0.81, o=6.5) OUTPUT: 00000000000000000000000000000000
# Attempt 626: **FAULT** (VCC=0.81, o=6.7) OUTPUT: 00000000000000000000000000000000
# Attempt 627: **FAULT** (VCC=0.81, o=7.0) OUTPUT: 00000000000000000000000000000000
# Attempt 628: **FAULT** (VCC=0.81, o=7.2) OUTPUT: 00000000000000000000000000000000
# Attempt 629: **FAULT** (VCC=0.81, o=7.5) OUTPUT: 00000000000000000000000000000000
# Attempt 630: **FAULT** (VCC=0.81, o=7.7) OUTPUT: 00000000000000000000000000000000
# Attempt 631: **FAULT** (VCC=0.81, o=8.0) OUTPUT: 00000000000000000000000000000000
# Attempt 632: **FAULT** (VCC=0.81, o=8.2) OUTPUT: 00000000000000000000000000000000
# Attempt 633: **FAULT** (VCC=0.81, o=8.5) OUTPUT: 00000000000000000000000000000000
# Attempt 634: **FAULT** (VCC=0.81, o=8.7) OUTPUT: 00000000000000000000000000000000
# Attempt 635: **FAULT** (VCC=0.81, o=9.0) OUTPUT: 00000000000000000000000000000000
# Attempt 636: **FAULT** (VCC=0.81, o=9.2) OUTPUT: 00000000000000000000000000000000
# Attempt 637: **FAULT** (VCC=0.81, o=9.5) OUTPUT: 00000000000000000000000000000000
# Attempt 638: **FAULT** (VCC=0.81, o=9.7) OUTPUT: 00000000000000000000000000000000
# Attempt 639: **FAULT** (VCC=0.81, o=10.0) OUTPUT: 00000000000000000000000000000000
# Attempt 640: **FAULT** (VCC=0.80, o=-10.0) OUTPUT: 00000000000000000000000000000000
# Attempt 641: **FAULT** (VCC=0.80, o=-9.7) OUTPUT: 00000000000000000000000000000000
# Attempt 642: **FAULT** (VCC=0.80, o=-9.5) OUTPUT: 00000000000000000000000000000000
# Attempt 643: **FAULT** (VCC=0.80, o=-9.2) OUTPUT: 00000000000000000000000000000000
# Attempt 644: **FAULT** (VCC=0.80, o=-9.0) OUTPUT: 00000000000000000000000000000000
# Attempt 645: **FAULT** (VCC=0.80, o=-8.7) OUTPUT: 00000000000000000000000000000000
# Attempt 646: **FAULT** (VCC=0.80, o=-8.5) OUTPUT: 00000000000000000000000000000000
# Attempt 647: **FAULT** (VCC=0.80, o=-8.2) OUTPUT: 00000000000000000000000000000000
# Attempt 648: **FAULT** (VCC=0.80, o=-8.0) OUTPUT: 00000000000000000000000000000000
# Attempt 649: **FAULT** (VCC=0.80, o=-7.7) OUTPUT: 00000000000000000000000000000000
# Attempt 650: **FAULT** (VCC=0.80, o=-7.5) OUTPUT: 00000000000000000000000000000000
# Attempt 651: **FAULT** (VCC=0.80, o=-7.2) OUTPUT: 00000000000000000000000000000000
# Attempt 652: **FAULT** (VCC=0.80, o=-7.0) OUTPUT: 00000000000000000000000000000000
# Attempt 653: **FAULT** (VCC=0.80, o=-6.7) OUTPUT: 00000000000000000000000000000000
# Attempt 654: **FAULT** (VCC=0.80, o=-6.5) OUTPUT: 00000000000000000000000000000000
# Attempt 655: **FAULT** (VCC=0.80, o=-6.2) OUTPUT: 00000000000000000000000000000000
# Attempt 656: **FAULT** (VCC=0.80, o=-5.9) OUTPUT: 00000000000000000000000000000000
# Attempt 657: **FAULT** (VCC=0.80, o=-5.7) OUTPUT: 00000000000000000000000000000000
# Attempt 658: **FAULT** (VCC=0.80, o=-5.4) OUTPUT: 00000000000000000000000000000000
# Attempt 659: **FAULT** (VCC=0.80, o=-5.2) OUTPUT: 00000000000000000000000000000000
# Attempt 660: **FAULT** (VCC=0.80, o=-4.9) OUTPUT: 00000000000000000000000000000000
# Attempt 661: **FAULT** (VCC=0.80, o=-4.7) OUTPUT: 00000000000000000000000000000000
# Attempt 662: **FAULT** (VCC=0.80, o=-4.4) OUTPUT: 00000000000000000000000000000000
# Attempt 663: **FAULT** (VCC=0.80, o=-4.2) OUTPUT: 00000000000000000000000000000000
# Attempt 664: **FAULT** (VCC=0.80, o=-3.9) OUTPUT: 00000000000000000000000000000000
# Attempt 665: **FAULT** (VCC=0.80, o=-3.7) OUTPUT: 00000000000000000000000000000000
# Attempt 666: **FAULT** (VCC=0.80, o=-3.4) OUTPUT: 00000000000000000000000000000000
# Attempt 667: **FAULT** (VCC=0.80, o=-3.2) OUTPUT: 00000000000000000000000000000000
# Attempt 668: **FAULT** (VCC=0.80, o=-2.9) OUTPUT: 00000000000000000000000000000000
# Attempt 669: **FAULT** (VCC=0.80, o=-2.7) OUTPUT: 00000000000000000000000000000000
# Attempt 670: **FAULT** (VCC=0.80, o=-2.4) OUTPUT: 00000000000000000000000000000000
# Attempt 671: **FAULT** (VCC=0.80, o=-2.2) OUTPUT: 00000000000000000000000000000000
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# Attempt 672: **FAULT** (VCC=0.80, o=-1.9) OUTPUT: 00000000000000000000000000000000
# Attempt 673: **FAULT** (VCC=0.80, o=-1.6) OUTPUT: 00000000000000000000000000000000
# Attempt 674: **FAULT** (VCC=0.80, o=-1.4) OUTPUT: 00000000000000000000000000000000
# Attempt 675: **FAULT** (VCC=0.80, o=-1.1) OUTPUT: 00000000000000000000000000000000
# Attempt 676: **FAULT** (VCC=0.80, o=-0.9) OUTPUT: 00000000000000000000000000000000
# Attempt 677: **FAULT** (VCC=0.80, o=-0.6) OUTPUT: 00000000000000000000000000000000
# Attempt 678: **FAULT** (VCC=0.80, o=-0.4) OUTPUT: 00000000000000000000000000000000
# Attempt 679: **FAULT** (VCC=0.80, o=-0.1) OUTPUT: 00000000000000000000000000000000
# Attempt 680: **FAULT** (VCC=0.80, o=0.1) OUTPUT: 00000000000000000000000000000000
# Attempt 681: **FAULT** (VCC=0.80, o=0.4) OUTPUT: 00000000000000000000000000000000
# Attempt 682: **FAULT** (VCC=0.80, o=0.6) OUTPUT: 00000000000000000000000000000000
# Attempt 683: **FAULT** (VCC=0.80, o=0.9) OUTPUT: 00000000000000000000000000000000
# Attempt 684: **FAULT** (VCC=0.80, o=1.1) OUTPUT: 00000000000000000000000000000000
# Attempt 685: **FAULT** (VCC=0.80, o=1.4) OUTPUT: 00000000000000000000000000000000
# Attempt 686: **FAULT** (VCC=0.80, o=1.6) OUTPUT: 00000000000000000000000000000000
# Attempt 687: **FAULT** (VCC=0.80, o=1.9) OUTPUT: 00000000000000000000000000000000
# Attempt 688: **FAULT** (VCC=0.80, o=2.2) OUTPUT: 00000000000000000000000000000000
# Attempt 689: **FAULT** (VCC=0.80, o=2.4) OUTPUT: 00000000000000000000000000000000
# Attempt 690: **FAULT** (VCC=0.80, o=2.7) OUTPUT: 00000000000000000000000000000000
# Attempt 691: **FAULT** (VCC=0.80, o=2.9) OUTPUT: 00000000000000000000000000000000
# Attempt 692: **FAULT** (VCC=0.80, o=3.2) OUTPUT: 00000000000000000000000000000000
# Attempt 693: **FAULT** (VCC=0.80, o=3.4) OUTPUT: 00000000000000000000000000000000
# Attempt 694: **FAULT** (VCC=0.80, o=3.7) OUTPUT: 00000000000000000000000000000000
# Attempt 695: **FAULT** (VCC=0.80, o=3.9) OUTPUT: 00000000000000000000000000000000
# Attempt 696: **FAULT** (VCC=0.80, o=4.2) OUTPUT: 00000000000000000000000000000000
# Attempt 697: **FAULT** (VCC=0.80, o=4.4) OUTPUT: 00000000000000000000000000000000
# Attempt 698: **FAULT** (VCC=0.80, o=4.7) OUTPUT: 00000000000000000000000000000000
# Attempt 699: **FAULT** (VCC=0.80, o=4.9) OUTPUT: 00000000000000000000000000000000
# Attempt 700: **FAULT** (VCC=0.80, o=5.2) OUTPUT: 00000000000000000000000000000000
# Attempt 701: **FAULT** (VCC=0.80, o=5.4) OUTPUT: 00000000000000000000000000000000
# Attempt 702: **FAULT** (VCC=0.80, o=5.7) OUTPUT: 00000000000000000000000000000000
# Attempt 703: **FAULT** (VCC=0.80, o=5.9) OUTPUT: 00000000000000000000000000000000
# Attempt 704: **FAULT** (VCC=0.80, o=6.2) OUTPUT: 00000000000000000000000000000000
# Attempt 705: **FAULT** (VCC=0.80, o=6.5) OUTPUT: 00000000000000000000000000000000
# Attempt 706: **FAULT** (VCC=0.80, o=6.7) OUTPUT: 00000000000000000000000000000000
# Attempt 707: **FAULT** (VCC=0.80, o=7.0) OUTPUT: 00000000000000000000000000000000
# Attempt 708: **FAULT** (VCC=0.80, o=7.2) OUTPUT: 00000000000000000000000000000000
# Attempt 709: **FAULT** (VCC=0.80, o=7.5) OUTPUT: 00000000000000000000000000000000
# Attempt 710: **FAULT** (VCC=0.80, o=7.7) OUTPUT: 00000000000000000000000000000000
# Attempt 711: **FAULT** (VCC=0.80, o=8.0) OUTPUT: 00000000000000000000000000000000
# Attempt 712: **FAULT** (VCC=0.80, o=8.2) OUTPUT: 00000000000000000000000000000000
# Attempt 713: **FAULT** (VCC=0.80, o=8.5) OUTPUT: 00000000000000000000000000000000
# Attempt 714: **FAULT** (VCC=0.80, o=8.7) OUTPUT: 00000000000000000000000000000000
# Attempt 715: **FAULT** (VCC=0.80, o=9.0) OUTPUT: 00000000000000000000000000000000
# Attempt 716: **FAULT** (VCC=0.80, o=9.2) OUTPUT: 00000000000000000000000000000000
# Attempt 717: **FAULT** (VCC=0.80, o=9.5) OUTPUT: 00000000000000000000000000000000
# Attempt 718: **FAULT** (VCC=0.80, o=9.7) OUTPUT: 00000000000000000000000000000000
# Attempt 719: **FAULT** (VCC=0.80, o=10.0) OUTPUT: 00000000000000000000000000000000
# Attempt 720: **FAULT** (VCC=0.79, o=-10.0) OUTPUT: 00000000000000000000000000000000
# Attempt 721: **FAULT** (VCC=0.79, o=-9.7) OUTPUT: 00000000000000000000000000000000
# Attempt 722: **FAULT** (VCC=0.79, o=-9.5) OUTPUT: 00000000000000000000000000000000
# Attempt 723: **FAULT** (VCC=0.79, o=-9.2) OUTPUT: 00000000000000000000000000000000
# Attempt 724: **FAULT** (VCC=0.79, o=-9.0) OUTPUT: 00000000000000000000000000000000
# Attempt 725: **FAULT** (VCC=0.79, o=-8.7) OUTPUT: 00000000000000000000000000000000
# Attempt 726: **FAULT** (VCC=0.79, o=-8.5) OUTPUT: 00000000000000000000000000000000
# Attempt 727: **FAULT** (VCC=0.79, o=-8.2) OUTPUT: 00000000000000000000000000000000
# Attempt 728: **FAULT** (VCC=0.79, o=-8.0) OUTPUT: 00000000000000000000000000000000
# Attempt 729: **FAULT** (VCC=0.79, o=-7.7) OUTPUT: 00000000000000000000000000000000
# Attempt 730: **FAULT** (VCC=0.79, o=-7.5) OUTPUT: 00000000000000000000000000000000
# Attempt 731: **FAULT** (VCC=0.79, o=-7.2) OUTPUT: 00000000000000000000000000000000
# Attempt 732: **FAULT** (VCC=0.79, o=-7.0) OUTPUT: 00000000000000000000000000000000
# Attempt 733: **FAULT** (VCC=0.79, o=-6.7) OUTPUT: 00000000000000000000000000000000
# Attempt 734: **FAULT** (VCC=0.79, o=-6.5) OUTPUT: 00000000000000000000000000000000
# Attempt 735: **FAULT** (VCC=0.79, o=-6.2) OUTPUT: 00000000000000000000000000000000
# Attempt 736: **FAULT** (VCC=0.79, o=-5.9) OUTPUT: 00000000000000000000000000000000
# Attempt 737: **FAULT** (VCC=0.79, o=-5.7) OUTPUT: 00000000000000000000000000000000
# Attempt 738: **FAULT** (VCC=0.79, o=-5.4) OUTPUT: 00000000000000000000000000000000
# Attempt 739: **FAULT** (VCC=0.79, o=-5.2) OUTPUT: 00000000000000000000000000000000
# Attempt 740: **FAULT** (VCC=0.79, o=-4.9) OUTPUT: 00000000000000000000000000000000
# Attempt 741: **FAULT** (VCC=0.79, o=-4.7) OUTPUT: 00000000000000000000000000000000
# Attempt 742: **FAULT** (VCC=0.79, o=-4.4) OUTPUT: 00000000000000000000000000000000
# Attempt 743: **FAULT** (VCC=0.79, o=-4.2) OUTPUT: 00000000000000000000000000000000
# Attempt 744: **FAULT** (VCC=0.79, o=-3.9) OUTPUT: 00000000000000000000000000000000
# Attempt 745: **FAULT** (VCC=0.79, o=-3.7) OUTPUT: 00000000000000000000000000000000
# Attempt 746: **FAULT** (VCC=0.79, o=-3.4) OUTPUT: 00000000000000000000000000000000
# Attempt 747: **FAULT** (VCC=0.79, o=-3.2) OUTPUT: 00000000000000000000000000000000
# Attempt 748: **FAULT** (VCC=0.79, o=-2.9) OUTPUT: 00000000000000000000000000000000
# Attempt 749: **FAULT** (VCC=0.79, o=-2.7) OUTPUT: 00000000000000000000000000000000
# Attempt 750: **FAULT** (VCC=0.79, o=-2.4) OUTPUT: 00000000000000000000000000000000
# Attempt 751: **FAULT** (VCC=0.79, o=-2.2) OUTPUT: 00000000000000000000000000000000
# Attempt 752: **FAULT** (VCC=0.79, o=-1.9) OUTPUT: 00000000000000000000000000000000
# Attempt 753: **FAULT** (VCC=0.79, o=-1.6) OUTPUT: 00000000000000000000000000000000
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# (ChipWhisperer Glitch WARNING|File ChipWhispererGlitch.py:793) Partial reconfiguration for offset = 0 may not work
# Attempt 754: **FAULT** (VCC=0.79, o=-1.4) OUTPUT: 00000000000000000000000000000000
# Attempt 755: **FAULT** (VCC=0.79, o=-1.1) OUTPUT: 00000000000000000000000000000000
# Attempt 756: **FAULT** (VCC=0.79, o=-0.9) OUTPUT: 00000000000000000000000000000000
# Attempt 757: **FAULT** (VCC=0.79, o=-0.6) OUTPUT: 00000000000000000000000000000000
# Attempt 758: **FAULT** (VCC=0.79, o=-0.4) OUTPUT: 00000000000000000000000000000000
# Attempt 759: **FAULT** (VCC=0.79, o=-0.1) OUTPUT: 00000000000000000000000000000000
# Attempt 760: **FAULT** (VCC=0.79, o=0.1) OUTPUT: 00000000000000000000000000000000
# Attempt 761: **FAULT** (VCC=0.79, o=0.4) OUTPUT: 00000000000000000000000000000000
# Attempt 762: **FAULT** (VCC=0.79, o=0.6) OUTPUT: 00000000000000000000000000000000
# Attempt 763: **FAULT** (VCC=0.79, o=0.9) OUTPUT: 00000000000000000000000000000000
# Attempt 764: **FAULT** (VCC=0.79, o=1.1) OUTPUT: 00000000000000000000000000000000
# Attempt 765: **FAULT** (VCC=0.79, o=1.4) OUTPUT: 00000000000000000000000000000000
# Attempt 766: **FAULT** (VCC=0.79, o=1.6) OUTPUT: 00000000000000000000000000000000
# Attempt 767: **FAULT** (VCC=0.79, o=1.9) OUTPUT: 00000000000000000000000000000000
# Attempt 768: **FAULT** (VCC=0.79, o=2.2) OUTPUT: 00000000000000000000000000000000
# Attempt 769: **FAULT** (VCC=0.79, o=2.4) OUTPUT: 00000000000000000000000000000000
# Attempt 770: **FAULT** (VCC=0.79, o=2.7) OUTPUT: 00000000000000000000000000000000
# Attempt 771: **FAULT** (VCC=0.79, o=2.9) OUTPUT: 00000000000000000000000000000000
# Attempt 772: **FAULT** (VCC=0.79, o=3.2) OUTPUT: 00000000000000000000000000000000
# Attempt 773: **FAULT** (VCC=0.79, o=3.4) OUTPUT: 00000000000000000000000000000000
# Attempt 774: **FAULT** (VCC=0.79, o=3.7) OUTPUT: 00000000000000000000000000000000
# Attempt 775: **FAULT** (VCC=0.79, o=3.9) OUTPUT: 00000000000000000000000000000000
# Attempt 776: **FAULT** (VCC=0.79, o=4.2) OUTPUT: 00000000000000000000000000000000
# Attempt 777: **FAULT** (VCC=0.79, o=4.4) OUTPUT: 00000000000000000000000000000000
# Attempt 778: **FAULT** (VCC=0.79, o=4.7) OUTPUT: 00000000000000000000000000000000
# Attempt 779: **FAULT** (VCC=0.79, o=4.9) OUTPUT: 00000000000000000000000000000000
# Attempt 780: **FAULT** (VCC=0.79, o=5.2) OUTPUT: 00000000000000000000000000000000
# Attempt 781: **FAULT** (VCC=0.79, o=5.4) OUTPUT: 00000000000000000000000000000000
# Attempt 782: **FAULT** (VCC=0.79, o=5.7) OUTPUT: 00000000000000000000000000000000
# Attempt 783: **FAULT** (VCC=0.79, o=5.9) OUTPUT: 00000000000000000000000000000000
# Attempt 784: **FAULT** (VCC=0.79, o=6.2) OUTPUT: 00000000000000000000000000000000
# Attempt 785: **FAULT** (VCC=0.79, o=6.5) OUTPUT: 00000000000000000000000000000000
# Attempt 786: **FAULT** (VCC=0.79, o=6.7) OUTPUT: 00000000000000000000000000000000
# Attempt 787: **FAULT** (VCC=0.79, o=7.0) OUTPUT: 00000000000000000000000000000000
# Attempt 788: **FAULT** (VCC=0.79, o=7.2) OUTPUT: 00000000000000000000000000000000
# Attempt 789: **FAULT** (VCC=0.79, o=7.5) OUTPUT: 00000000000000000000000000000000
# Attempt 790: **FAULT** (VCC=0.79, o=7.7) OUTPUT: 00000000000000000000000000000000
# Attempt 791: **FAULT** (VCC=0.79, o=8.0) OUTPUT: 00000000000000000000000000000000
# Attempt 792: **FAULT** (VCC=0.79, o=8.2) OUTPUT: 00000000000000000000000000000000
# Attempt 793: **FAULT** (VCC=0.79, o=8.5) OUTPUT: 00000000000000000000000000000000
# Attempt 794: **FAULT** (VCC=0.79, o=8.7) OUTPUT: 00000000000000000000000000000000
# Attempt 795: **FAULT** (VCC=0.79, o=9.0) OUTPUT: 00000000000000000000000000000000
# Attempt 796: **FAULT** (VCC=0.79, o=9.2) OUTPUT: 00000000000000000000000000000000
# Attempt 797: **FAULT** (VCC=0.79, o=9.5) OUTPUT: 00000000000000000000000000000000
# Attempt 798: **FAULT** (VCC=0.79, o=9.7) OUTPUT: 00000000000000000000000000000000
# Attempt 799: **FAULT** (VCC=0.79, o=10.0) OUTPUT: 00000000000000000000000000000000

# %%
glitched_results = []
successful_faults = 0
successful_params = []
# --- VCC_INT SWEEP DEFINITION ---
# Start safe (1.0V) and go down to crash point (0.70V), in 10 steps
VCC_INT_TARGET = 0.9
VCC_SWEEP = np.linspace(0.9, 0.84, 10)  # VCC_SWEEP range from 1.0V to 0.70V

# --- OFFSET SWEEP DEFINITION ---
OFFSETS = np.linspace(-40.0, 40.0, 80)
FIXED_WIDTH = 4
ATTEMPTS_PER_POINT = 1

print("\n--- Starting Nested VCC/Offset Sweep ---")
print(f"Total Attempts: {len(VCC_SWEEP) * len(OFFSETS) * ATTEMPTS_PER_POINT}")


for vcc in VCC_SWEEP:
    # 1. SET THE NEW VULNERABLE VOLTAGE
    target.vccint_set(vcc)
    scope.glitch.width = FIXED_WIDTH
    
    # 2. SWEEP OFFSET AT THIS VOLTAGE LEVEL
    for offset in OFFSETS:
        scope.glitch.offset = offset
        
        # 3. ATTEMPT GLITCH MULTIPLE TIMES
        for attempt in range(ATTEMPTS_PER_POINT):
            
            i = len(glitched_results) # Tracking total attempts
            
            scope.arm()
            output, success = run_aes(target, PLAINTEXT, KEY)

            # --- CRASH & REPROGRAM LOGIC ---
            if scope.capture():
                # Handle timeout/crash
                try:
                    target.fpga_write(BITSTREAM_FILEPATH)
                except:
                    pass
                # Log the crash for plotting later
                glitched_results.append({'result': 'TIMEOUT', 'vcc': vcc, 'offset': offset})
                print(f"Attempt {i}: TIMEOUT (VCC={vcc:.2f}, o={offset:.1f}). Reprogrammed.")
                continue
            
            # --- FAULT DETECTION LOGIC ---
            output_hex = output.hex() if output else "N/A"
            expected_hex = EXPECTED_CIPHERTEXT.hex()
            
            if output_hex != expected_hex:
                result = 'FAULT'
                successful_faults += 1
            else:
                result = 'NORMAL'
                
            # Log the result
            glitched_results.append({'result': result, 'vcc': vcc, 'offset': offset, 'output': output_hex})
            
            # --- MODIFIED PRINT STATEMENT TO SHOW OUTPUT ---
            if result == 'FAULT':
                print(f"Attempt {i}: **FAULT** (VCC={vcc:.2f}, o={offset:.1f}) OUTPUT: {output_hex}")
                successful_params.append({'vcc': vcc, 'offset': offset, 'output': output_hex})
            else:
                # Prints the correct output for monitoring
                print(f"Attempt {i}: Normal (VCC={vcc:.2f}, o={offset:.1f}) OUTPUT: {output_hex}")
# Out:
#   Cell In[7], line 20
#     target.vccint_set(vcc)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 18

# %%
import numpy as np

# --- FINAL TARGETED GLITCH PARAMETERS ---

# Setting the pulse width back to the successful level (4.0%)
FIXED_WIDTH = 4.0 

# Sweeping VCC-INT into the vulnerable zone in fine steps (e.g., 0.01V steps)
VCC_SWEEP_RANGE = np.linspace(0.88, 0.87, 4) 

# Sweep Offset still covers the vulnerable region
SWEEP_OFFSETS = np.linspace(-10.0, 10.0, 40) # 40 steps for faster iteration

ATTEMPTS_PER_POINT = 2

# --- INITIALIZE LISTS ---
glitched_results = []
successful_faults = 0
total_attempts_run = 0

print("\n--- Starting Glitch Sweep (Lower VCC, Wider Pulse) ---")
print(f"Glitch Width: {FIXED_WIDTH}%. VCC Range: {VCC_SWEEP_RANGE[0]:.2f}V to {VCC_SWEEP_RANGE[-1]:.2f}V")

scope.glitch.width = FIXED_WIDTH
scope.glitch.repeat = 1

# Outer loop sweeps VCC_INT
for vcc in VCC_SWEEP_RANGE:
    target.vccint_set(vcc)
    
    # Inner loop sweeps Offset
    for offset in SWEEP_OFFSETS:
        scope.glitch.offset = offset
        
        for attempt in range(ATTEMPTS_PER_POINT):
            
            i = total_attempts_run
            total_attempts_run += 1
            
            scope.arm()
            output, success = run_aes(target, PLAINTEXT, KEY)

            # --- CRASH & REPROGRAM LOGIC ---
            if scope.capture():
                # Reprogram FPGA after crash
                try:
                    target.fpga_write(BITSTREAM_FILEPATH)
                except:
                    pass
                glitched_results.append({'result': 'TIMEOUT', 'vcc': vcc, 'offset': offset})
                # We expect TIMEOUTs here, but we need to log them.
                continue
            
            # --- FAULT DETECTION LOGIC ---
            output_hex = output.hex() if output else "N/A"
            expected_hex = EXPECTED_CIPHERTEXT.hex()
            
            if output_hex != expected_hex:
                result = 'FAULT'
                successful_faults += 1
                glitched_results.append({'result': result, 'vcc': vcc, 'offset': offset, 'output': output_hex})
                print(f"Attempt {i}: **FAULT** (VCC={vcc:.2f}, o={offset:.2f}) OUTPUT: {output_hex}")
                break
                
            else:
                result = 'NORMAL'

            glitched_results.append({'result': result, 'vcc': vcc, 'offset': offset, 'output': output_hex})
            
            # --- OUTPUT MONITORING ---
            if result == 'FAULT':
                # Highlight the successful faults
                print(f"Attempt {i}: **FAULT** (VCC={vcc:.2f}, o={offset:.2f}) OUTPUT: {output_hex}")
            elif result == 'NORMAL' and (i % 20) == 0:
                # Print only occasional normal results
                print(f"Attempt {i}: Normal (VCC={vcc:.2f}, o={offset:.2f}) OUTPUT: {output_hex}")
# Out:
# --- Starting Glitch Sweep (Lower VCC, Wider Pulse) ---
# Glitch Width: 4.0%. VCC Range: 0.88V to 0.87V
# Attempt 0: Normal (VCC=0.88, o=-10.00) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 20: Normal (VCC=0.88, o=-4.87) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 40: Normal (VCC=0.88, o=0.26) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 60: Normal (VCC=0.88, o=5.38) OUTPUT: 06f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 80: **FAULT** (VCC=0.88, o=-10.00) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 81: **FAULT** (VCC=0.88, o=-9.49) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 82: **FAULT** (VCC=0.88, o=-8.97) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 83: **FAULT** (VCC=0.88, o=-8.46) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 84: **FAULT** (VCC=0.88, o=-7.95) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 85: **FAULT** (VCC=0.88, o=-7.44) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 86: **FAULT** (VCC=0.88, o=-6.92) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 87: **FAULT** (VCC=0.88, o=-6.41) OUTPUT: 04f36a65e8a99fd8907b2e5e5ddd77de
# Attempt 88: **FAULT** (VCC=0.88, o=-5.90) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 89: **FAULT** (VCC=0.88, o=-5.38) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 90: **FAULT** (VCC=0.88, o=-4.87) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 91: **FAULT** (VCC=0.88, o=-4.36) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 92: **FAULT** (VCC=0.88, o=-3.85) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 93: **FAULT** (VCC=0.88, o=-3.33) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 94: **FAULT** (VCC=0.88, o=-2.82) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 95: **FAULT** (VCC=0.88, o=-2.31) OUTPUT: 04f36a65e8a99fd8907b2e5e5ddd57de
# Attempt 96: **FAULT** (VCC=0.88, o=-1.79) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 97: **FAULT** (VCC=0.88, o=-1.28) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 98: **FAULT** (VCC=0.88, o=-0.77) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 99: **FAULT** (VCC=0.88, o=-0.26) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 100: **FAULT** (VCC=0.88, o=0.26) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 101: **FAULT** (VCC=0.88, o=0.77) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 102: **FAULT** (VCC=0.88, o=1.28) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 103: **FAULT** (VCC=0.88, o=1.79) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 104: **FAULT** (VCC=0.88, o=2.31) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 105: **FAULT** (VCC=0.88, o=2.82) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 106: **FAULT** (VCC=0.88, o=3.33) OUTPUT: 04f36a65e8a99fd8907b2e5e5ddd57de
# Attempt 107: **FAULT** (VCC=0.88, o=3.85) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd57de
# Attempt 108: **FAULT** (VCC=0.88, o=4.36) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 109: **FAULT** (VCC=0.88, o=4.87) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 110: **FAULT** (VCC=0.88, o=5.38) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 111: **FAULT** (VCC=0.88, o=5.90) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 112: **FAULT** (VCC=0.88, o=6.41) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 113: **FAULT** (VCC=0.88, o=6.92) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 114: **FAULT** (VCC=0.88, o=7.44) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 115: **FAULT** (VCC=0.88, o=7.95) OUTPUT: 04f36a65e8a99fd8907b2e5e5ddd77de
# Attempt 116: **FAULT** (VCC=0.88, o=8.46) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 117: **FAULT** (VCC=0.88, o=8.97) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 118: **FAULT** (VCC=0.88, o=9.49) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 119: **FAULT** (VCC=0.88, o=10.00) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 120: **FAULT** (VCC=0.87, o=-10.00) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 121: **FAULT** (VCC=0.87, o=-9.49) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 122: **FAULT** (VCC=0.87, o=-8.97) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 123: **FAULT** (VCC=0.87, o=-8.46) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 124: **FAULT** (VCC=0.87, o=-7.95) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 125: **FAULT** (VCC=0.87, o=-7.44) OUTPUT: 04f36a65e8a99fd8907b2e5e5ddd77de
# Attempt 126: **FAULT** (VCC=0.87, o=-6.92) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 127: **FAULT** (VCC=0.87, o=-6.41) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 128: **FAULT** (VCC=0.87, o=-5.90) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 129: **FAULT** (VCC=0.87, o=-5.38) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 130: **FAULT** (VCC=0.87, o=-4.87) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 131: **FAULT** (VCC=0.87, o=-4.36) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 132: **FAULT** (VCC=0.87, o=-3.85) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 133: **FAULT** (VCC=0.87, o=-3.33) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 134: **FAULT** (VCC=0.87, o=-2.82) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 135: **FAULT** (VCC=0.87, o=-2.31) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 136: **FAULT** (VCC=0.87, o=-1.79) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 137: **FAULT** (VCC=0.87, o=-1.28) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 138: **FAULT** (VCC=0.87, o=-0.77) OUTPUT: 04f36a65e8a99ff8907b0e5e5ddd77de
# Attempt 139: **FAULT** (VCC=0.87, o=-0.26) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 140: **FAULT** (VCC=0.87, o=0.26) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd57de
# Attempt 141: **FAULT** (VCC=0.87, o=0.77) OUTPUT: 04f36a65e8a99fd8907b2e5e5ddd77de
# Attempt 142: **FAULT** (VCC=0.87, o=1.28) OUTPUT: 04f36a65e8a99fd8907b2e5e5ddd77de
# Attempt 143: **FAULT** (VCC=0.87, o=1.79) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 144: **FAULT** (VCC=0.87, o=2.31) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 145: **FAULT** (VCC=0.87, o=2.82) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 146: **FAULT** (VCC=0.87, o=3.33) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 147: **FAULT** (VCC=0.87, o=3.85) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 148: **FAULT** (VCC=0.87, o=4.36) OUTPUT: 04f36a65e8a99fd8907b2e5e5ddd77de
# Attempt 149: **FAULT** (VCC=0.87, o=4.87) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 150: **FAULT** (VCC=0.87, o=5.38) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 151: **FAULT** (VCC=0.87, o=5.90) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 152: **FAULT** (VCC=0.87, o=6.41) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 153: **FAULT** (VCC=0.87, o=6.92) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 154: **FAULT** (VCC=0.87, o=7.44) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 155: **FAULT** (VCC=0.87, o=7.95) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 156: **FAULT** (VCC=0.87, o=8.46) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 157: **FAULT** (VCC=0.87, o=8.97) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 158: **FAULT** (VCC=0.87, o=9.49) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 159: **FAULT** (VCC=0.87, o=10.00) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 160: **FAULT** (VCC=0.87, o=-10.00) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 161: **FAULT** (VCC=0.87, o=-9.49) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 162: **FAULT** (VCC=0.87, o=-8.97) OUTPUT: 04f36a65e8a99fd8907b2e5e5ddd77de
# Attempt 163: **FAULT** (VCC=0.87, o=-8.46) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 164: **FAULT** (VCC=0.87, o=-7.95) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 165: **FAULT** (VCC=0.87, o=-7.44) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 166: **FAULT** (VCC=0.87, o=-6.92) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 167: **FAULT** (VCC=0.87, o=-6.41) OUTPUT: 04f36a65e8a99fd8907b2e5e5ddd57de
# Attempt 168: **FAULT** (VCC=0.87, o=-5.90) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 169: **FAULT** (VCC=0.87, o=-5.38) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 170: **FAULT** (VCC=0.87, o=-4.87) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 171: **FAULT** (VCC=0.87, o=-4.36) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 172: **FAULT** (VCC=0.87, o=-3.85) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 173: **FAULT** (VCC=0.87, o=-3.33) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 174: **FAULT** (VCC=0.87, o=-2.82) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 175: **FAULT** (VCC=0.87, o=-2.31) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 176: **FAULT** (VCC=0.87, o=-1.79) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 177: **FAULT** (VCC=0.87, o=-1.28) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 178: **FAULT** (VCC=0.87, o=-0.77) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 179: **FAULT** (VCC=0.87, o=-0.26) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 180: **FAULT** (VCC=0.87, o=0.26) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 181: **FAULT** (VCC=0.87, o=0.77) OUTPUT: 04f36a65e8a99df8907b0e5e5ddd77de
# Attempt 182: **FAULT** (VCC=0.87, o=1.28) OUTPUT: 04f36a65e8a99ff8907b0e5e5ddd77de
# Attempt 183: **FAULT** (VCC=0.87, o=1.79) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 184: **FAULT** (VCC=0.87, o=2.31) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 185: **FAULT** (VCC=0.87, o=2.82) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 186: **FAULT** (VCC=0.87, o=3.33) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 187: **FAULT** (VCC=0.87, o=3.85) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 188: **FAULT** (VCC=0.87, o=4.36) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 189: **FAULT** (VCC=0.87, o=4.87) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 190: **FAULT** (VCC=0.87, o=5.38) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 191: **FAULT** (VCC=0.87, o=5.90) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 192: **FAULT** (VCC=0.87, o=6.41) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 193: **FAULT** (VCC=0.87, o=6.92) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 194: **FAULT** (VCC=0.87, o=7.44) OUTPUT: 04f36a65e8a99ff8907b0e5e5ddd57de
# Attempt 195: **FAULT** (VCC=0.87, o=7.95) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 196: **FAULT** (VCC=0.87, o=8.46) OUTPUT: 04f36a65e8a99ff8907b0e5e5ddd77de
# Attempt 197: **FAULT** (VCC=0.87, o=8.97) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 198: **FAULT** (VCC=0.87, o=9.49) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de
# Attempt 199: **FAULT** (VCC=0.87, o=10.00) OUTPUT: 04f36a65e8a99ff8907b2e5e5ddd77de

# %%
# --- FINALIZED SWEET SPOT PARAMETERS ---
VCC_FINAL = 0.87      # Stable fault voltage
OFFSET_FINAL = -10.00 # Offset that consistently yields the fault
WIDTH_FINAL = 4.0     # Finalized width

# --- INITIALIZE FOR SINGLE ATTEMPT ---
glitched_trace_for_plot = None
attempt_result = None

target.vccint_set(VCC_FINAL)
scope.glitch.width = WIDTH_FINAL
scope.glitch.offset = OFFSET_FINAL
scope.glitch.repeat = 1

print(f"\n--- COLLECTING SINGLE FAULT TRACE at VCC={VCC_FINAL}V, Offset={OFFSET_FINAL} ---")

# Run loop until a successful fault trace is collected (max 10 attempts for stability)
for i in range(10): 
    scope.arm()
    output, success = run_aes(target, PLAINTEXT, KEY)

    if scope.capture():
        # Handle crash (reprogram if needed)
        try:
            target.fpga_write(BITSTREAM_FILEPATH)
            print(f"Attempt {i}: TIMEOUT. Reprogrammed.")
        except:
            pass
        continue

    output_hex = output.hex()
    expected_hex = EXPECTED_CIPHERTEXT.hex()
    
    if output_hex != expected_hex and success:
        # A true fault occurred, and communication was successful
        glitched_trace_for_plot = scope.get_last_trace()
        attempt_result = output_hex
        print(f"SUCCESS: Fault Trace Collected. Output: {attempt_result}")
        break
    else:
        # Normal run, not crash. Continue attempting.
        print(f"Attempt {i}: Normal result. Re-attempting fault...")
        
# Set VCC-INT back to a safe level immediately
target.vccint_set(1.0)
# Out:
# --- COLLECTING SINGLE FAULT TRACE at VCC=0.87V, Offset=-10.0 ---
# SUCCESS: Fault Trace Collected. Output: 04f36a65e8a99ff8907b2e5e5ddd77de

# %%
import matplotlib.pyplot as plt
import numpy as np

if glitched_trace_for_plot is None:
    print("\nError: Failed to capture a valid FAULT trace after 10 attempts. Check VCC_FINAL/Offset settings.")
else:
    # --- PREPARE PLOT DATA ---
    baseline_trace = np.array(normal_traces[0])
    glitched_trace = np.array(glitched_trace_for_plot)
    
    # Ensure traces have the same length
    min_len = min(len(glitched_trace), len(baseline_trace))
    glitched_trace = glitched_trace[:min_len]
    baseline_trace = baseline_trace[:min_len]

    # --- PLOT THE COMPARISON ---
    plt.figure(figsize=(12, 6))
    
    plt.plot(baseline_trace, label="Baseline (Normal) Trace", color='blue', linewidth=1.5)
    plt.plot(glitched_trace, 
             label=f"FAULT Trace (VCC={VCC_FINAL:.2f}V, Offset={OFFSET_FINAL:.2f})", 
             color='red', linewidth=1.0, alpha=0.7)
    
    plt.title("Comparison of Normal vs. Glitched Power Trace at Sweet Spot")
    plt.xlabel(f"Sample Number (Total Samples: {min_len})")
    plt.ylabel("Power Consumption (ADC Units)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. DETERMINE BASELINE TRACE ---
if len(normal_traces) == 0:
    print("Error: The 'normal_traces' list is empty. Cannot perform comparison.")
    # You must go back and run the 'CAPTURE NORMAL TRACES' section.
    # We will exit the function here, as a comparison without a normal trace is impossible.
else:
    baseline_trace = np.array(normal_traces[0])
    
    # --- 2. SEARCH FOR BEST GLITCHED TRACE ---
    glitched_data = None
    
    # Iterate backwards to find the MOST RECENT stable fault (less likely to be corrupted)
    for result in reversed(glitched_results):
        if result.get('result') == 'FAULT':
            # We must ensure the 'trace' key exists AND has data (length > 0)
            if result.get('trace') is not None and len(result['trace']) > 0:
                glitched_data = result
                break
    
    # --- 3. PREPARE PLOT DATA ---
    if glitched_data:
        glitched_trace = np.array(glitched_data['trace'])
        fault_vcc = glitched_data.get('vcc')
        fault_offset = glitched_data.get('offset')
        glitch_label = f"FAULT Trace (VCC={fault_vcc:.2f}V, Offset={fault_offset:.2f})"
        
        # Ensure traces have the same length before plotting
        if len(glitched_trace) != len(baseline_trace):
             # Traces have different lengths (e.g., partial capture on glitch). Use shorter length for plot range.
             min_len = min(len(glitched_trace), len(baseline_trace))
             glitched_trace = glitched_trace[:min_len]
             baseline_trace = baseline_trace[:min_len]
             print(f"Warning: Traces had different lengths. Plotting only {min_len} samples.")

    else:
        print("Warning: No complete FAULT traces found. Plotting baseline vs. dummy trace.")
        glitched_trace = baseline_trace # Plot baseline twice if no fault trace exists
        glitch_label = "No Usable FAULT Trace Found (Showing Baseline Twice)"
        
    # --- 4. PLOT THE COMPARISON ---
    plt.figure(figsize=(12, 6))
    
    # Plot the normal baseline trace (Blue)
    plt.plot(baseline_trace, label="Baseline (Normal) Trace", color='blue', linewidth=1.5)
    
    # Plot the faulty trace (Red)
    plt.plot(glitched_trace, label=glitch_label, color='red', linewidth=1.0, alpha=0.7)
    
    plt.title("Comparison of Normal vs. Glitched Power Trace")
    plt.xlabel("Sample Number")
    plt.ylabel("Power Consumption (ADC Units)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# Warning: No complete FAULT traces found. Plotting baseline vs. dummy trace.

# %%
# --- FINALIZED SWEET SPOT PARAMETERS ---
VCC_FINAL = 0.88      # Stable fault voltage
OFFSET_FINAL = -10.00 # Offset that consistently yields the fault
WIDTH_FINAL = 4.0     # Finalized width

# --- INITIALIZE FOR SINGLE ATTEMPT ---
glitched_trace_for_plot = None
attempt_result = None

target.vccint_set(VCC_FINAL)
scope.glitch.width = WIDTH_FINAL
scope.glitch.offset = OFFSET_FINAL
scope.glitch.repeat = 50

print(f"\n--- COLLECTING SINGLE FAULT TRACE at VCC={VCC_FINAL}V, Offset={OFFSET_FINAL} ---")

# Run loop until a successful fault trace is collected (max 10 attempts for stability)
for i in range(500): 
    scope.arm()
    output, success = run_aes(target, PLAINTEXT, KEY)

    if scope.capture():
        # Handle crash (reprogram if needed)
        try:
            target.fpga_write(BITSTREAM_FILEPATH)
            print(f"Attempt {i}: TIMEOUT. Reprogrammed.")
        except:
            pass
        continue

    output_hex = output.hex()
    expected_hex = EXPECTED_CIPHERTEXT.hex()
    
    if output_hex != expected_hex and success:
        # A true fault occurred, and communication was successful
        glitched_trace_for_plot = scope.get_last_trace()
        attempt_result = output_hex
        print(f"SUCCESS: Fault Trace Collected. Output: {attempt_result}")
        break
    else:
        # Normal run, not crash. Continue attempting.
        print(f"Attempt {i}: Normal result. Re-attempting fault...")
        
# Set VCC-INT back to a safe level immediately
target.vccint_set(1.0)
# Out:
# --- COLLECTING SINGLE FAULT TRACE at VCC=0.88V, Offset=-10.0 ---
# Attempt 0: Normal result. Re-attempting fault...
# Attempt 1: Normal result. Re-attempting fault...
# Attempt 2: Normal result. Re-attempting fault...
# Attempt 3: Normal result. Re-attempting fault...
# Attempt 4: Normal result. Re-attempting fault...
# Attempt 5: Normal result. Re-attempting fault...
# Attempt 6: Normal result. Re-attempting fault...
# Attempt 7: Normal result. Re-attempting fault...
# Attempt 8: Normal result. Re-attempting fault...
# Attempt 9: Normal result. Re-attempting fault...
# Attempt 10: Normal result. Re-attempting fault...
# Attempt 11: Normal result. Re-attempting fault...
# Attempt 12: Normal result. Re-attempting fault...
# Attempt 13: Normal result. Re-attempting fault...
# Attempt 14: Normal result. Re-attempting fault...
# Attempt 15: Normal result. Re-attempting fault...
# Attempt 16: Normal result. Re-attempting fault...
# Attempt 17: Normal result. Re-attempting fault...
# Attempt 18: Normal result. Re-attempting fault...
# Attempt 19: Normal result. Re-attempting fault...
# Attempt 20: Normal result. Re-attempting fault...
# Attempt 21: Normal result. Re-attempting fault...
# Attempt 22: Normal result. Re-attempting fault...
# Attempt 23: Normal result. Re-attempting fault...
# Attempt 24: Normal result. Re-attempting fault...
# Attempt 25: Normal result. Re-attempting fault...
# Attempt 26: Normal result. Re-attempting fault...
# Attempt 27: Normal result. Re-attempting fault...
# Attempt 28: Normal result. Re-attempting fault...
# Attempt 29: Normal result. Re-attempting fault...
# Attempt 30: Normal result. Re-attempting fault...
# Attempt 31: Normal result. Re-attempting fault...
